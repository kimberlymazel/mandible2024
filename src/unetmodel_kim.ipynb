# %%
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from keras import backend as K

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 11663062827186235081
# xla_global_id: -1
# ]

# %%
def conv_block(x, num_filters):
    x = Conv2D(num_filters, (3,3), padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, (3,3), padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

# %%
def build_model(shape):
    num_filters = [64, 128, 256, 512]
    inputs = Input(shape)

    skip_x = []
    x = inputs
    
    # ENCODER
    for f in num_filters:
        x = conv_block(x, f)
        skip_x.append(x)
        x = MaxPooling2D((2, 2))(x)

    # BRIDGE
    x = conv_block(x, 1024)

    num_filters.reverse()
    skip_x.reverse()

    # DECODER
    for i, f in enumerate(num_filters):
        x = UpSampling2D((2, 2))(x)
        xs = skip_x[i]

        # Apply cropping or padding to match shapes
        diff_h = xs.shape[1] - x.shape[1]
        diff_w = xs.shape[2] - x.shape[2]

        if diff_h > 0:
            x = ZeroPadding2D(((0, diff_h), (0, 0)))(x)
        elif diff_h < 0:
            xs = ZeroPadding2D(((0, -diff_h), (0, 0)))(xs)

        if diff_w > 0:
            x = ZeroPadding2D(((0, 0), (0, diff_w)))(x)
        elif diff_w < 0:
            xs = ZeroPadding2D(((0, 0), (0, -diff_w)))(xs)

        x = Concatenate()([x, xs])
        x = conv_block(x, f)
    
    # OUTPUT
    x = Conv2D(1, (1, 1), padding="same")(x)  # Output with 1 channel
    x = Activation("sigmoid")(x)

    return Model(inputs, x)

# %%
input_shape = (300, 130, 3)  
model = build_model(input_shape)
print(model.summary())
# Out:
# Model: "functional_11"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_14      │ (None, 300, 130,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_166 (Conv2D) │ (None, 300, 130,  │      1,792 │ input_layer_14[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 300, 130,  │        256 │ conv2d_166[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_155      │ (None, 300, 130,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_167 (Conv2D) │ (None, 300, 130,  │     36,928 │ activation_155[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 300, 130,  │        256 │ conv2d_167[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_156      │ (None, 300, 130,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_48    │ (None, 150, 65,   │          0 │ activation_156[0… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_168 (Conv2D) │ (None, 150, 65,   │     73,856 │ max_pooling2d_48… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 150, 65,   │        512 │ conv2d_168[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_157      │ (None, 150, 65,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_169 (Conv2D) │ (None, 150, 65,   │    147,584 │ activation_157[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 150, 65,   │        512 │ conv2d_169[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_158      │ (None, 150, 65,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_49    │ (None, 75, 32,    │          0 │ activation_158[0… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_170 (Conv2D) │ (None, 75, 32,    │    295,168 │ max_pooling2d_49… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 75, 32,    │      1,024 │ conv2d_170[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_159      │ (None, 75, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_171 (Conv2D) │ (None, 75, 32,    │    590,080 │ activation_159[0… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 75, 32,    │      1,024 │ conv2d_171[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_160      │ (None, 75, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_50    │ (None, 37, 16,    │          0 │ activation_160[0… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_172 (Conv2D) │ (None, 37, 16,    │  1,180,160 │ max_pooling2d_50… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 37, 16,    │      2,048 │ conv2d_172[0][0]  │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_161      │ (None, 37, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_173 (Conv2D) │ (None, 37, 16,    │  2,359,808 │ activation_161[0… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 37, 16,    │      2,048 │ conv2d_173[0][0]  │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_162      │ (None, 37, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_51    │ (None, 18, 8,     │          0 │ activation_162[0… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_174 (Conv2D) │ (None, 18, 8,     │  4,719,616 │ max_pooling2d_51… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 18, 8,     │      4,096 │ conv2d_174[0][0]  │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_163      │ (None, 18, 8,     │          0 │ batch_normalizat… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_175 (Conv2D) │ (None, 18, 8,     │  9,438,208 │ activation_163[0… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 18, 8,     │      4,096 │ conv2d_175[0][0]  │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_164      │ (None, 18, 8,     │          0 │ batch_normalizat… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_26    │ (None, 36, 16,    │          0 │ activation_164[0… │
# │ (UpSampling2D)      │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_3    │ (None, 37, 16,    │          0 │ up_sampling2d_26… │
# │ (ZeroPadding2D)     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_23      │ (None, 37, 16,    │          0 │ zero_padding2d_3… │
# │ (Concatenate)       │ 1536)             │            │ activation_162[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_176 (Conv2D) │ (None, 37, 16,    │  7,078,400 │ concatenate_23[0… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 37, 16,    │      2,048 │ conv2d_176[0][0]  │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_165      │ (None, 37, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_177 (Conv2D) │ (None, 37, 16,    │  2,359,808 │ activation_165[0… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 37, 16,    │      2,048 │ conv2d_177[0][0]  │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_166      │ (None, 37, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_27    │ (None, 74, 32,    │          0 │ activation_166[0… │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_4    │ (None, 75, 32,    │          0 │ up_sampling2d_27… │
# │ (ZeroPadding2D)     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_24      │ (None, 75, 32,    │          0 │ zero_padding2d_4… │
# │ (Concatenate)       │ 768)              │            │ activation_160[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_178 (Conv2D) │ (None, 75, 32,    │  1,769,728 │ concatenate_24[0… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 75, 32,    │      1,024 │ conv2d_178[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_167      │ (None, 75, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_179 (Conv2D) │ (None, 75, 32,    │    590,080 │ activation_167[0… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 75, 32,    │      1,024 │ conv2d_179[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_168      │ (None, 75, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_28    │ (None, 150, 64,   │          0 │ activation_168[0… │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_5    │ (None, 150, 65,   │          0 │ up_sampling2d_28… │
# │ (ZeroPadding2D)     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_25      │ (None, 150, 65,   │          0 │ zero_padding2d_5… │
# │ (Concatenate)       │ 384)              │            │ activation_158[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_180 (Conv2D) │ (None, 150, 65,   │    442,496 │ concatenate_25[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 150, 65,   │        512 │ conv2d_180[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_169      │ (None, 150, 65,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_181 (Conv2D) │ (None, 150, 65,   │    147,584 │ activation_169[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 150, 65,   │        512 │ conv2d_181[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_170      │ (None, 150, 65,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_29    │ (None, 300, 130,  │          0 │ activation_170[0… │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_26      │ (None, 300, 130,  │          0 │ up_sampling2d_29… │
# │ (Concatenate)       │ 192)              │            │ activation_156[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_182 (Conv2D) │ (None, 300, 130,  │    110,656 │ concatenate_26[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 300, 130,  │        256 │ conv2d_182[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_171      │ (None, 300, 130,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_183 (Conv2D) │ (None, 300, 130,  │     36,928 │ activation_171[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 300, 130,  │        256 │ conv2d_183[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_172      │ (None, 300, 130,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_184 (Conv2D) │ (None, 300, 130,  │         65 │ activation_172[0… │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_173      │ (None, 300, 130,  │          0 │ conv2d_184[0][0]  │
# │ (Activation)        │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 31,402,497 (119.79 MB)
#  Trainable params: 31,390,721 (119.75 MB)
#  Non-trainable params: 11,776 (46.00 KB)
# None

# %%
import numpy as np

trainimageNP = np.load("../dataset/augmented/feed/train_img.npy")
trainmaskNP = np.load("../dataset/augmented/feed/train_mask.npy")
validimageNP = np.load("../dataset/augmented/feed/valid_img.npy")
validmaskNP = np.load("../dataset/augmented/feed/valid_mask.npy")

# %%
print(trainimageNP.shape)
print(trainmaskNP.shape)
print(validimageNP.shape)
print(validmaskNP.shape)
# Out:
# (2091, 300, 130, 3)
# (2091, 300, 130)
# (233, 300, 130, 3)
# (233, 300, 130)

# %%
lr = 1e-4
batchSize = 32
epochs = 50

# %%
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

# Compile the model
opt = tf.keras.optimizers.Adam(lr)
model.compile(loss="binary_crossentropy", optimizer=opt, metrics=["accuracy"])

# Calculate steps per epoch and validation steps
stepsPerEpoch = len(trainimageNP) // batchSize
validationSteps = len(validimageNP) // batchSize

# Define the best model file path
best_model_file = "../dataset/augmented/unet-cnn.keras"

# Define callbacks
callbacks = [
    ModelCheckpoint(best_model_file, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor="val_loss", patience=5, factor=0.1, verbose=1, min_lr=1e-7),
    EarlyStopping(monitor="val_loss", patience=20, verbose=1, mode="min")
]

# Train the model
history = model.fit(trainimageNP, trainmaskNP,
                    batch_size=batchSize,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(validimageNP, validmaskNP),
                    validation_steps=validationSteps,
                    steps_per_epoch=stepsPerEpoch,
                    shuffle=True,
                    callbacks=callbacks
                    )
# Out:
# Epoch 1/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 48s/step - accuracy: 0.9732 - loss: 0.0718
# Epoch 1: val_loss improved from inf to 0.10463, saving model to ../dataset/augmented/unet-cnn.keras
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3272s 49s/step - accuracy: 0.9732 - loss: 0.0717 - val_accuracy: 0.9608 - val_loss: 0.1046 - learning_rate: 1.0000e-04
# Epoch 2/50
#  1/65 ━━━━━━━━━━━━━━━━━━━━ 10:58 10s/step - accuracy: 0.9772 - loss: 0.0597
# c:\Users\kimbe\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(value)
# Epoch 2: val_loss improved from 0.10463 to 0.10285, saving model to ../dataset/augmented/unet-cnn.keras
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 14s 66ms/step - accuracy: 0.9772 - loss: 0.0597 - val_accuracy: 0.9598 - val_loss: 0.1029 - learning_rate: 1.0000e-04
# Epoch 3/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 40s/step - accuracy: 0.9819 - loss: 0.0503
# Epoch 3: val_loss improved from 0.10285 to 0.06168, saving model to ../dataset/augmented/unet-cnn.keras
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2697s 40s/step - accuracy: 0.9819 - loss: 0.0502 - val_accuracy: 0.9779 - val_loss: 0.0617 - learning_rate: 1.0000e-04
# Epoch 4/50
#  1/65 ━━━━━━━━━━━━━━━━━━━━ 9:07 9s/step - accuracy: 0.9853 - loss: 0.0402
# Epoch 4: val_loss did not improve from 0.06168
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 11s 31ms/step - accuracy: 0.9853 - loss: 0.0402 - val_accuracy: 0.9776 - val_loss: 0.0644 - learning_rate: 1.0000e-04
# Epoch 5/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 27s/step - accuracy: 0.9877 - loss: 0.0352
# Epoch 5: val_loss improved from 0.06168 to 0.05138, saving model to ../dataset/augmented/unet-cnn.keras
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1808s 28s/step - accuracy: 0.9877 - loss: 0.0352 - val_accuracy: 0.9817 - val_loss: 0.0514 - learning_rate: 1.0000e-04
# Epoch 6/50
#  1/65 ━━━━━━━━━━━━━━━━━━━━ 9:06 9s/step - accuracy: 0.9877 - loss: 0.0345
# Epoch 6: val_loss did not improve from 0.05138
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 11s 31ms/step - accuracy: 0.9877 - loss: 0.0345 - val_accuracy: 0.9792 - val_loss: 0.0592 - learning_rate: 1.0000e-04
# Epoch 7/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 25s/step - accuracy: 0.9906 - loss: 0.0274
# Epoch 7: val_loss improved from 0.05138 to 0.04478, saving model to ../dataset/augmented/unet-cnn.keras
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1701s 26s/step - accuracy: 0.9906 - loss: 0.0274 - val_accuracy: 0.9839 - val_loss: 0.0448 - learning_rate: 1.0000e-04
# Epoch 8/50
#  1/65 ━━━━━━━━━━━━━━━━━━━━ 9:06 9s/step - accuracy: 0.9874 - loss: 0.0346
# Epoch 8: val_loss did not improve from 0.04478
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 11s 32ms/step - accuracy: 0.9874 - loss: 0.0346 - val_accuracy: 0.9828 - val_loss: 0.0493 - learning_rate: 1.0000e-04
# Epoch 9/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 26s/step - accuracy: 0.9919 - loss: 0.0236
# Epoch 9: val_loss improved from 0.04478 to 0.03698, saving model to ../dataset/augmented/unet-cnn.keras
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1761s 27s/step - accuracy: 0.9919 - loss: 0.0236 - val_accuracy: 0.9873 - val_loss: 0.0370 - learning_rate: 1.0000e-04
# Epoch 10/50
#  1/65 ━━━━━━━━━━━━━━━━━━━━ 8:44 8s/step - accuracy: 0.9923 - loss: 0.0220
# Epoch 10: val_loss did not improve from 0.03698
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - accuracy: 0.9923 - loss: 0.0220 - val_accuracy: 0.9846 - val_loss: 0.0460 - learning_rate: 1.0000e-04
# Epoch 11/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 27s/step - accuracy: 0.9934 - loss: 0.0193
# Epoch 11: val_loss improved from 0.03698 to 0.03255, saving model to ../dataset/augmented/unet-cnn.keras
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1783s 27s/step - accuracy: 0.9934 - loss: 0.0193 - val_accuracy: 0.9889 - val_loss: 0.0325 - learning_rate: 1.0000e-04
# Epoch 12/50
#  1/65 ━━━━━━━━━━━━━━━━━━━━ 10:46 10s/step - accuracy: 0.9935 - loss: 0.0194
# Epoch 12: val_loss did not improve from 0.03255
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 12s 36ms/step - accuracy: 0.9935 - loss: 0.0194 - val_accuracy: 0.9847 - val_loss: 0.0459 - learning_rate: 1.0000e-04
# Epoch 13/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 26s/step - accuracy: 0.9943 - loss: 0.0167
# Epoch 13: val_loss improved from 0.03255 to 0.03118, saving model to ../dataset/augmented/unet-cnn.keras
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1749s 27s/step - accuracy: 0.9943 - loss: 0.0167 - val_accuracy: 0.9897 - val_loss: 0.0312 - learning_rate: 1.0000e-04
# Epoch 14/50
#  1/65 ━━━━━━━━━━━━━━━━━━━━ 8:46 8s/step - accuracy: 0.9957 - loss: 0.0129
# Epoch 14: val_loss did not improve from 0.03118
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.9957 - loss: 0.0129 - val_accuracy: 0.9857 - val_loss: 0.0458 - learning_rate: 1.0000e-04
# Epoch 15/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 27s/step - accuracy: 0.9952 - loss: 0.0142
# Epoch 15: val_loss improved from 0.03118 to 0.02960, saving model to ../dataset/augmented/unet-cnn.keras
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1775s 27s/step - accuracy: 0.9952 - loss: 0.0142 - val_accuracy: 0.9904 - val_loss: 0.0296 - learning_rate: 1.0000e-04
# Epoch 16/50
#  1/65 ━━━━━━━━━━━━━━━━━━━━ 8:42 8s/step - accuracy: 0.9958 - loss: 0.0132
# Epoch 16: val_loss did not improve from 0.02960
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - accuracy: 0.9958 - loss: 0.0132 - val_accuracy: 0.9875 - val_loss: 0.0419 - learning_rate: 1.0000e-04
# Epoch 17/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 26s/step - accuracy: 0.9955 - loss: 0.0132
# Epoch 17: val_loss improved from 0.02960 to 0.02951, saving model to ../dataset/augmented/unet-cnn.keras
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1708s 26s/step - accuracy: 0.9955 - loss: 0.0132 - val_accuracy: 0.9904 - val_loss: 0.0295 - learning_rate: 1.0000e-04
# Epoch 18/50
#  1/65 ━━━━━━━━━━━━━━━━━━━━ 8:48 8s/step - accuracy: 0.9961 - loss: 0.0116
# Epoch 18: val_loss did not improve from 0.02951
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.9961 - loss: 0.0116 - val_accuracy: 0.9859 - val_loss: 0.0491 - learning_rate: 1.0000e-04
# Epoch 19/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 26s/step - accuracy: 0.9960 - loss: 0.0115
# Epoch 19: val_loss improved from 0.02951 to 0.02834, saving model to ../dataset/augmented/unet-cnn.keras
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1736s 27s/step - accuracy: 0.9960 - loss: 0.0115 - val_accuracy: 0.9911 - val_loss: 0.0283 - learning_rate: 1.0000e-04
# Epoch 20/50
#  1/65 ━━━━━━━━━━━━━━━━━━━━ 9:00 8s/step - accuracy: 0.9962 - loss: 0.0108
# Epoch 20: val_loss did not improve from 0.02834
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 10s 32ms/step - accuracy: 0.9962 - loss: 0.0108 - val_accuracy: 0.9872 - val_loss: 0.0445 - learning_rate: 1.0000e-04
# Epoch 21/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 26s/step - accuracy: 0.9962 - loss: 0.0110
# Epoch 21: val_loss improved from 0.02834 to 0.02652, saving model to ../dataset/augmented/unet-cnn.keras
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1726s 26s/step - accuracy: 0.9962 - loss: 0.0110 - val_accuracy: 0.9917 - val_loss: 0.0265 - learning_rate: 1.0000e-04
# Epoch 22/50
#  1/65 ━━━━━━━━━━━━━━━━━━━━ 10:24 10s/step - accuracy: 0.9970 - loss: 0.0089
# Epoch 22: val_loss did not improve from 0.02652
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 12s 36ms/step - accuracy: 0.9970 - loss: 0.0089 - val_accuracy: 0.9871 - val_loss: 0.0454 - learning_rate: 1.0000e-04
# Epoch 23/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 26s/step - accuracy: 0.9966 - loss: 0.0099
# Epoch 23: val_loss did not improve from 0.02652
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1768s 27s/step - accuracy: 0.9966 - loss: 0.0099 - val_accuracy: 0.9918 - val_loss: 0.0270 - learning_rate: 1.0000e-04
# Epoch 24/50
#  1/65 ━━━━━━━━━━━━━━━━━━━━ 9:28 9s/step - accuracy: 0.9963 - loss: 0.0112
# Epoch 24: val_loss did not improve from 0.02652
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 11s 32ms/step - accuracy: 0.9963 - loss: 0.0112 - val_accuracy: 0.9877 - val_loss: 0.0432 - learning_rate: 1.0000e-04
# Epoch 25/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 27s/step - accuracy: 0.9970 - loss: 0.0088
# Epoch 25: val_loss did not improve from 0.02652
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1786s 27s/step - accuracy: 0.9970 - loss: 0.0088 - val_accuracy: 0.9915 - val_loss: 0.0280 - learning_rate: 1.0000e-04
# Epoch 26/50
#  1/65 ━━━━━━━━━━━━━━━━━━━━ 8:53 8s/step - accuracy: 0.9968 - loss: 0.0090
# Epoch 26: val_loss did not improve from 0.02652
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 10s 32ms/step - accuracy: 0.9968 - loss: 0.0090 - val_accuracy: 0.9871 - val_loss: 0.0475 - learning_rate: 1.0000e-04
# Epoch 27/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 26s/step - accuracy: 0.9973 - loss: 0.0079
# Epoch 27: val_loss improved from 0.02652 to 0.02504, saving model to ../dataset/augmented/unet-cnn.keras
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1752s 27s/step - accuracy: 0.9973 - loss: 0.0079 - val_accuracy: 0.9929 - val_loss: 0.0250 - learning_rate: 1.0000e-05
# Epoch 28/50
#  1/65 ━━━━━━━━━━━━━━━━━━━━ 10:27 10s/step - accuracy: 0.9969 - loss: 0.0092
# Epoch 28: val_loss did not improve from 0.02504
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9969 - loss: 0.0092 - val_accuracy: 0.9886 - val_loss: 0.0443 - learning_rate: 1.0000e-05
# Epoch 29/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 26s/step - accuracy: 0.9983 - loss: 0.0062
# Epoch 29: val_loss did not improve from 0.02504
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1780s 27s/step - accuracy: 0.9983 - loss: 0.0062 - val_accuracy: 0.9931 - val_loss: 0.0252 - learning_rate: 1.0000e-05
# Epoch 30/50
#  1/65 ━━━━━━━━━━━━━━━━━━━━ 9:04 9s/step - accuracy: 0.9984 - loss: 0.0058
# Epoch 30: val_loss did not improve from 0.02504
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 11s 33ms/step - accuracy: 0.9984 - loss: 0.0058 - val_accuracy: 0.9887 - val_loss: 0.0452 - learning_rate: 1.0000e-05
# Epoch 31/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 27s/step - accuracy: 0.9985 - loss: 0.0056
# Epoch 31: val_loss did not improve from 0.02504
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1787s 27s/step - accuracy: 0.9985 - loss: 0.0056 - val_accuracy: 0.9932 - val_loss: 0.0253 - learning_rate: 1.0000e-05
# Epoch 32/50
#  1/65 ━━━━━━━━━━━━━━━━━━━━ 10:46 10s/step - accuracy: 0.9981 - loss: 0.0059
# Epoch 32: val_loss did not improve from 0.02504
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 13s 43ms/step - accuracy: 0.9981 - loss: 0.0059 - val_accuracy: 0.9889 - val_loss: 0.0455 - learning_rate: 1.0000e-05
# Epoch 33/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 27s/step - accuracy: 0.9986 - loss: 0.0054
# Epoch 33: val_loss did not improve from 0.02504
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1808s 28s/step - accuracy: 0.9986 - loss: 0.0054 - val_accuracy: 0.9932 - val_loss: 0.0255 - learning_rate: 1.0000e-06
# Epoch 34/50
#  1/65 ━━━━━━━━━━━━━━━━━━━━ 10:11 10s/step - accuracy: 0.9991 - loss: 0.0043
# Epoch 34: val_loss did not improve from 0.02504
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9991 - loss: 0.0043 - val_accuracy: 0.9889 - val_loss: 0.0458 - learning_rate: 1.0000e-06
# Epoch 35/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 26s/step - accuracy: 0.9986 - loss: 0.0054
# Epoch 35: val_loss did not improve from 0.02504
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1742s 27s/step - accuracy: 0.9986 - loss: 0.0054 - val_accuracy: 0.9932 - val_loss: 0.0257 - learning_rate: 1.0000e-06
# Epoch 36/50
#  1/65 ━━━━━━━━━━━━━━━━━━━━ 9:08 9s/step - accuracy: 0.9981 - loss: 0.0061
# Epoch 36: val_loss did not improve from 0.02504
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 11s 31ms/step - accuracy: 0.9981 - loss: 0.0061 - val_accuracy: 0.9889 - val_loss: 0.0461 - learning_rate: 1.0000e-06
# Epoch 37/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 27s/step - accuracy: 0.9987 - loss: 0.0053
# Epoch 37: val_loss did not improve from 0.02504
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 1e-07.
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1820s 28s/step - accuracy: 0.9987 - loss: 0.0053 - val_accuracy: 0.9932 - val_loss: 0.0258 - learning_rate: 1.0000e-06
# Epoch 38/50
#  1/65 ━━━━━━━━━━━━━━━━━━━━ 9:05 9s/step - accuracy: 0.9987 - loss: 0.0052
# Epoch 38: val_loss did not improve from 0.02504
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 11s 32ms/step - accuracy: 0.9987 - loss: 0.0052 - val_accuracy: 0.9890 - val_loss: 0.0462 - learning_rate: 1.0000e-07
# Epoch 39/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 26s/step - accuracy: 0.9986 - loss: 0.0054
# Epoch 39: val_loss did not improve from 0.02504
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1745s 26s/step - accuracy: 0.9986 - loss: 0.0054 - val_accuracy: 0.9932 - val_loss: 0.0258 - learning_rate: 1.0000e-07
# Epoch 40/50
#  1/65 ━━━━━━━━━━━━━━━━━━━━ 9:18 9s/step - accuracy: 0.9988 - loss: 0.0049
# Epoch 40: val_loss did not improve from 0.02504
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 11s 33ms/step - accuracy: 0.9988 - loss: 0.0049 - val_accuracy: 0.9890 - val_loss: 0.0464 - learning_rate: 1.0000e-07
# Epoch 41/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 26s/step - accuracy: 0.9987 - loss: 0.0052
# Epoch 41: val_loss did not improve from 0.02504
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1762s 27s/step - accuracy: 0.9987 - loss: 0.0052 - val_accuracy: 0.9932 - val_loss: 0.0259 - learning_rate: 1.0000e-07
# Epoch 42/50
#  1/65 ━━━━━━━━━━━━━━━━━━━━ 10:31 10s/step - accuracy: 0.9990 - loss: 0.0044
# Epoch 42: val_loss did not improve from 0.02504
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 13s 49ms/step - accuracy: 0.9990 - loss: 0.0044 - val_accuracy: 0.9890 - val_loss: 0.0465 - learning_rate: 1.0000e-07
# Epoch 43/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 26s/step - accuracy: 0.9987 - loss: 0.0053
# Epoch 43: val_loss did not improve from 0.02504
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1732s 27s/step - accuracy: 0.9987 - loss: 0.0053 - val_accuracy: 0.9932 - val_loss: 0.0259 - learning_rate: 1.0000e-07
# Epoch 44/50
#  1/65 ━━━━━━━━━━━━━━━━━━━━ 10:34 10s/step - accuracy: 0.9989 - loss: 0.0046
# Epoch 44: val_loss did not improve from 0.02504
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 12s 34ms/step - accuracy: 0.9989 - loss: 0.0046 - val_accuracy: 0.9890 - val_loss: 0.0465 - learning_rate: 1.0000e-07
# Epoch 45/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 26s/step - accuracy: 0.9986 - loss: 0.0053
# Epoch 45: val_loss did not improve from 0.02504
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1735s 26s/step - accuracy: 0.9986 - loss: 0.0053 - val_accuracy: 0.9932 - val_loss: 0.0259 - learning_rate: 1.0000e-07
# Epoch 46/50
#  1/65 ━━━━━━━━━━━━━━━━━━━━ 9:56 9s/step - accuracy: 0.9988 - loss: 0.0055
# Epoch 46: val_loss did not improve from 0.02504
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 12s 36ms/step - accuracy: 0.9988 - loss: 0.0055 - val_accuracy: 0.9889 - val_loss: 0.0465 - learning_rate: 1.0000e-07
# Epoch 47/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 25s/step - accuracy: 0.9986 - loss: 0.0053
# Epoch 47: val_loss did not improve from 0.02504
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1686s 26s/step - accuracy: 0.9986 - loss: 0.0053 - val_accuracy: 0.9932 - val_loss: 0.0259 - learning_rate: 1.0000e-07
# Epoch 47: early stopping

# %%
import cv2

model = tf.keras.models.load_model("../dataset/augmented/unet-cnn.keras")

width = 130
height = 300

imgpath = "../dataset/annotations2/0413594-1.tiff"
img = cv2.imread(imgpath)
img2 = cv2.resize(img, (width, height))
img2 = img2/255.0
img3 = np.expand_dims(img2, axis=0)

pred = model.predict(img3)
resultMask = pred[0]

print(resultMask)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# [[[0.00663859]
#   [0.00560077]
#   [0.00384687]
#   ...
#   [0.00242746]
#   [0.00227475]
#   [0.00160943]]
#
#  [[0.00376154]
#   [0.00373219]
#   [0.00344169]
#   ...
#   [0.00153265]
#   [0.00231978]
#   [0.00168021]]
#
#  [[0.00289578]
#   [0.00197902]
#   [0.0028565 ]
#   ...
#   [0.00178062]
#   [0.00149872]
#   [0.00191482]]
#
#  ...
#
#  [[0.0030442 ]
#   [0.00123614]
#   [0.00119245]
#   ...
#   [0.00214818]
#   [0.0023466 ]
#   [0.00249374]]
#
#  [[0.00607744]
#   [0.00295033]
#   [0.00173992]
#   ...
#   [0.00197823]
#   [0.00319493]
#   [0.00408875]]
#
#  [[0.00510855]
#   [0.004769  ]
#   [0.00233243]
#   ...
#   [0.00448683]
#   [0.01021888]
#   [0.00764655]]]

# %%
resultMask[resultMask <=0.5] = 0
resultMask[resultMask > 0.5] = 255

scale_percent = 20

w = int(img.shape[1] * scale_percent/100)
h = int(img.shape[0] * scale_percent/100)

dim = (w,h)

img = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
mask = cv2.resize(resultMask, dim, interpolation = cv2.INTER_AREA)

cv2.imshow("image", img)
cv2.imshow("mask", mask)
cv2.waitKey(0)
# Out:
# -1
