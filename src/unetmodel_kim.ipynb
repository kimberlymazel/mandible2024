# %%
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model

# %%
def conv_block(x, num_filters):
    x = Conv2D(num_filters, (3,3), padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, (3,3), padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

# %%
def build_model(shape):
    num_filters = [64, 128, 256, 512]
    inputs = Input((shape))

    skip_x = []
    x = inputs
    
    # ENCODER
    for f in num_filters:
        x = conv_block(x, f)
        skip_x.append(x)
        x = MaxPool2D((2, 2))(x)

    # BRIDGE
    x = conv_block(x, 1024)

    num_filters.reverse()
    skip_x.reverse()


    # DECODER
    for i, f in enumerate(num_filters):
        x = UpSampling2D((2,2))(x)
        xs = skip_x[i]
        x = Concatenate()([x, xs])
        x = conv_block(x, f)
    
    # OUTPUT
    x = Conv2D(1, (1,1), padding="same")(x)
    x = Activation("sigmoid")(x)

    return Model(inputs, x)

# %%
input_shape = (256, 256, 3)  
model = build_model(input_shape)
print(model.summary())
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_6       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_72 (Conv2D)  │ (None, 256, 256,  │      1,792 │ input_layer_6[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ conv2d_72[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_72       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_73 (Conv2D)  │ (None, 256, 256,  │     36,928 │ activation_72[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ conv2d_73[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_73       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_24    │ (None, 128, 128,  │          0 │ activation_73[0]… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_74 (Conv2D)  │ (None, 128, 128,  │     73,856 │ max_pooling2d_24… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ conv2d_74[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_74       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_75 (Conv2D)  │ (None, 128, 128,  │    147,584 │ activation_74[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ conv2d_75[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_75       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_25    │ (None, 64, 64,    │          0 │ activation_75[0]… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_76 (Conv2D)  │ (None, 64, 64,    │    295,168 │ max_pooling2d_25… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ conv2d_76[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_76       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_77 (Conv2D)  │ (None, 64, 64,    │    590,080 │ activation_76[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ conv2d_77[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_77       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_26    │ (None, 32, 32,    │          0 │ activation_77[0]… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_78 (Conv2D)  │ (None, 32, 32,    │  1,180,160 │ max_pooling2d_26… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      2,048 │ conv2d_78[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_78       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_79 (Conv2D)  │ (None, 32, 32,    │  2,359,808 │ activation_78[0]… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      2,048 │ conv2d_79[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_79       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_27    │ (None, 16, 16,    │          0 │ activation_79[0]… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_80 (Conv2D)  │ (None, 16, 16,    │  4,719,616 │ max_pooling2d_27… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      4,096 │ conv2d_80[0][0]   │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_80       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_81 (Conv2D)  │ (None, 16, 16,    │  9,438,208 │ activation_80[0]… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      4,096 │ conv2d_81[0][0]   │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_81       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_12    │ (None, 32, 32,    │          0 │ activation_81[0]… │
# │ (UpSampling2D)      │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_11      │ (None, 32, 32,    │          0 │ up_sampling2d_12… │
# │ (Concatenate)       │ 1536)             │            │ activation_79[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_82 (Conv2D)  │ (None, 32, 32,    │  7,078,400 │ concatenate_11[0… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      2,048 │ conv2d_82[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_82       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_83 (Conv2D)  │ (None, 32, 32,    │  2,359,808 │ activation_82[0]… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      2,048 │ conv2d_83[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_83       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_13    │ (None, 64, 64,    │          0 │ activation_83[0]… │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_12      │ (None, 64, 64,    │          0 │ up_sampling2d_13… │
# │ (Concatenate)       │ 768)              │            │ activation_77[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_84 (Conv2D)  │ (None, 64, 64,    │  1,769,728 │ concatenate_12[0… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ conv2d_84[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_84       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_85 (Conv2D)  │ (None, 64, 64,    │    590,080 │ activation_84[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ conv2d_85[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_85       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_14    │ (None, 128, 128,  │          0 │ activation_85[0]… │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_13      │ (None, 128, 128,  │          0 │ up_sampling2d_14… │
# │ (Concatenate)       │ 384)              │            │ activation_75[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_86 (Conv2D)  │ (None, 128, 128,  │    442,496 │ concatenate_13[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ conv2d_86[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_86       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_87 (Conv2D)  │ (None, 128, 128,  │    147,584 │ activation_86[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ conv2d_87[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_87       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_15    │ (None, 256, 256,  │          0 │ activation_87[0]… │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_14      │ (None, 256, 256,  │          0 │ up_sampling2d_15… │
# │ (Concatenate)       │ 192)              │            │ activation_73[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_88 (Conv2D)  │ (None, 256, 256,  │    110,656 │ concatenate_14[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ conv2d_88[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_88       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_89 (Conv2D)  │ (None, 256, 256,  │     36,928 │ activation_88[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ conv2d_89[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_89       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_90 (Conv2D)  │ (None, 256, 256,  │         65 │ activation_89[0]… │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_90       │ (None, 256, 256,  │          0 │ conv2d_90[0][0]   │
# │ (Activation)        │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 31,402,497 (119.79 MB)
#  Trainable params: 31,390,721 (119.75 MB)
#  Non-trainable params: 11,776 (46.00 KB)
# None

# %%
import numpy as np

trainimageNP = np.load("../dataset/xpm_annotate/feed/train_img.npy")
trainmaskNP = np.load("../dataset/xpm_annotate/feed/train_mask.npy")
validimageNP = np.load("../dataset/xpm_annotate/feed/valid_img.npy")
validmaskNP = np.load("../dataset/xpm_annotate/feed/valid_mask.npy")

# %%
print(trainimageNP.shape)
print(trainmaskNP.shape)
print(validimageNP.shape)
print(validmaskNP.shape)
# Out:
# (122, 310, 130, 3)
# (122, 310, 130)
# (14, 310, 130, 3)
# (14, 310, 130)

# %%
input_shape = (310, 130, 3)  
model = build_model(input_shape)
print(model.summary())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 2
#       1 input_shape = (310, 130, 3)
# ----> 2 model = build_model(input_shape)
#       3 print(model.summary())
#
# Cell In[24], line 25, in build_model(shape)
#      23     x = UpSampling2D((2,2))(x)
#      24     xs = skip_x[i]
# ---> 25     x = Concatenate()([x, xs])
#      26     x = conv_block(x, f)
#      28 # OUTPUT
#
# File c:\Users\kimbe\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\Users\kimbe\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\merging\concatenate.py:97, in Concatenate.build(self, input_shape)
#      91         unique_dims = set(
#      92             shape[axis]
#      93             for shape in shape_set
#      94             if shape[axis] is not None
#      95         )
#      96         if len(unique_dims) > 1:
# ---> 97             raise ValueError(err_msg)
#      98 self.built = True
#
# ValueError: A `Concatenate` layer requires inputs with matching shapes except for the concatenation axis. Received: input_shape=[(None, 76, 32, 512), (None, 77, 32, 256)]

# %%
lr = 1e-4
batchSize = 4
epochs = 50

# %%
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

opt = tf.keras.optimizers.Adam(lr)
model.compile(loss="binary_crossentropy", optimizer = opt, metrics=["accuracy"])

stepsPerEpoch = int(np.ceil(len(trainimageNP) / batchSize))
validationSteps = int(np.ceil(len(validimageNP) / batchSize))

best_model_file = "../test/unet-cnn.keras"

callbacks = [
    ModelCheckpoint(best_model_file, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor="val_loss", patience=5, factor=0.1, verbose=1, min_lr = 1e-7),
    EarlyStopping(monitor="val_accuracy", patience=20, verbose = 1)
]

history = model.fit(trainimageNP, trainmaskNP,
                    batch_size = batchSize,
                    epochs = epochs,
                    verbose = 1,
                    validation_data=(validimageNP, validmaskNP),
                    validation_steps = validationSteps,
                    steps_per_epoch = stepsPerEpoch,
                    shuffle = True,
                    callbacks=callbacks
                    )
# Out:
# Epoch 1/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.7767 - loss: 0.4703
# Epoch 1: val_loss improved from inf to 0.81173, saving model to ../test/unet-cnn.keras
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 193s 6s/step - accuracy: 0.7787 - loss: 0.4675 - val_accuracy: 0.3918 - val_loss: 0.8117 - learning_rate: 1.0000e-04
# Epoch 2/50
#
# Epoch 2: val_loss improved from 0.81173 to 0.00000, saving model to ../test/unet-cnn.keras
# c:\Users\kimbe\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(value)
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 3/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.8930 - loss: 0.2677
# Epoch 3: val_loss did not improve from 0.00000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 160s 5s/step - accuracy: 0.8930 - loss: 0.2676 - val_accuracy: 0.4205 - val_loss: 1.1365 - learning_rate: 1.0000e-04
# Epoch 4/50
#
# Epoch 4: val_loss did not improve from 0.00000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 841us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 5/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.8899 - loss: 0.2638
# Epoch 5: val_loss did not improve from 0.00000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 179s 6s/step - accuracy: 0.8901 - loss: 0.2634 - val_accuracy: 0.5812 - val_loss: 0.6650 - learning_rate: 1.0000e-04
# Epoch 6/50
#
# Epoch 6: val_loss did not improve from 0.00000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 7/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.9095 - loss: 0.2178
# Epoch 7: val_loss did not improve from 0.00000
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 181s 6s/step - accuracy: 0.9095 - loss: 0.2177 - val_accuracy: 0.6373 - val_loss: 0.6248 - learning_rate: 1.0000e-04
# Epoch 8/50
#
# Epoch 8: val_loss did not improve from 0.00000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 9/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.9174 - loss: 0.1973
# Epoch 9: val_loss did not improve from 0.00000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 191s 6s/step - accuracy: 0.9175 - loss: 0.1972 - val_accuracy: 0.7728 - val_loss: 0.5458 - learning_rate: 1.0000e-05
# Epoch 10/50
#
# Epoch 10: val_loss did not improve from 0.00000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 11/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.9212 - loss: 0.1912
# Epoch 11: val_loss did not improve from 0.00000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 189s 6s/step - accuracy: 0.9212 - loss: 0.1910 - val_accuracy: 0.7565 - val_loss: 0.5192 - learning_rate: 1.0000e-05
# Epoch 12/50
#
# Epoch 12: val_loss did not improve from 0.00000
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 13/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.9260 - loss: 0.1790
# Epoch 13: val_loss did not improve from 0.00000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 193s 6s/step - accuracy: 0.9261 - loss: 0.1789 - val_accuracy: 0.7332 - val_loss: 0.4878 - learning_rate: 1.0000e-06
# Epoch 14/50
#
# Epoch 14: val_loss did not improve from 0.00000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-06
# Epoch 15/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9305 - loss: 0.1714
# Epoch 15: val_loss did not improve from 0.00000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 174s 6s/step - accuracy: 0.9304 - loss: 0.1716 - val_accuracy: 0.7293 - val_loss: 0.4690 - learning_rate: 1.0000e-06
# Epoch 16/50
#
# Epoch 16: val_loss did not improve from 0.00000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-06
# Epoch 17/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.9251 - loss: 0.1818
# Epoch 17: val_loss did not improve from 0.00000
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1e-07.
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 180s 6s/step - accuracy: 0.9251 - loss: 0.1817 - val_accuracy: 0.7272 - val_loss: 0.4762 - learning_rate: 1.0000e-06
# Epoch 18/50
#
# Epoch 18: val_loss did not improve from 0.00000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-07
# Epoch 19/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.9270 - loss: 0.1771
# Epoch 19: val_loss did not improve from 0.00000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 177s 6s/step - accuracy: 0.9270 - loss: 0.1771 - val_accuracy: 0.7324 - val_loss: 0.4887 - learning_rate: 1.0000e-07
# Epoch 20/50
#
# Epoch 20: val_loss did not improve from 0.00000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-07
# Epoch 21/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.9271 - loss: 0.1749
# Epoch 21: val_loss did not improve from 0.00000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 200s 6s/step - accuracy: 0.9271 - loss: 0.1749 - val_accuracy: 0.7398 - val_loss: 0.4946 - learning_rate: 1.0000e-07
# Epoch 22/50
#
# Epoch 22: val_loss did not improve from 0.00000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-07
# Epoch 23/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.9299 - loss: 0.1712
# Epoch 23: val_loss did not improve from 0.00000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 194s 6s/step - accuracy: 0.9298 - loss: 0.1714 - val_accuracy: 0.7513 - val_loss: 0.4850 - learning_rate: 1.0000e-07
# Epoch 24/50
#
# Epoch 24: val_loss did not improve from 0.00000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-07
# Epoch 25/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.9294 - loss: 0.1726
# Epoch 25: val_loss did not improve from 0.00000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 195s 6s/step - accuracy: 0.9294 - loss: 0.1727 - val_accuracy: 0.7680 - val_loss: 0.4602 - learning_rate: 1.0000e-07
# Epoch 26/50
#
# Epoch 26: val_loss did not improve from 0.00000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-07
# Epoch 27/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9257 - loss: 0.1779
# Epoch 27: val_loss did not improve from 0.00000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 164s 5s/step - accuracy: 0.9258 - loss: 0.1778 - val_accuracy: 0.7932 - val_loss: 0.4189 - learning_rate: 1.0000e-07
# Epoch 28/50
#
# Epoch 28: val_loss did not improve from 0.00000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-07
# Epoch 29/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9291 - loss: 0.1722
# Epoch 29: val_loss did not improve from 0.00000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 163s 5s/step - accuracy: 0.9290 - loss: 0.1723 - val_accuracy: 0.8223 - val_loss: 0.3699 - learning_rate: 1.0000e-07
# Epoch 30/50
#
# Epoch 30: val_loss did not improve from 0.00000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-07
# Epoch 31/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9208 - loss: 0.1888
# Epoch 31: val_loss did not improve from 0.00000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 169s 5s/step - accuracy: 0.9209 - loss: 0.1884 - val_accuracy: 0.8520 - val_loss: 0.3201 - learning_rate: 1.0000e-07
# Epoch 32/50
#
# Epoch 32: val_loss did not improve from 0.00000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-07
# Epoch 33/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9266 - loss: 0.1783
# Epoch 33: val_loss did not improve from 0.00000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 161s 5s/step - accuracy: 0.9266 - loss: 0.1783 - val_accuracy: 0.8782 - val_loss: 0.2752 - learning_rate: 1.0000e-07
# Epoch 34/50
#
# Epoch 34: val_loss did not improve from 0.00000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-07
# Epoch 35/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9300 - loss: 0.1712
# Epoch 35: val_loss did not improve from 0.00000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 158s 5s/step - accuracy: 0.9300 - loss: 0.1713 - val_accuracy: 0.8987 - val_loss: 0.2397 - learning_rate: 1.0000e-07
# Epoch 36/50
#
# Epoch 36: val_loss did not improve from 0.00000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-07
# Epoch 37/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9268 - loss: 0.1769
# Epoch 37: val_loss did not improve from 0.00000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 159s 5s/step - accuracy: 0.9268 - loss: 0.1770 - val_accuracy: 0.9108 - val_loss: 0.2159 - learning_rate: 1.0000e-07
# Epoch 38/50
#
# Epoch 38: val_loss did not improve from 0.00000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-07
# Epoch 39/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9247 - loss: 0.1795
# Epoch 39: val_loss did not improve from 0.00000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 159s 5s/step - accuracy: 0.9248 - loss: 0.1794 - val_accuracy: 0.9175 - val_loss: 0.2007 - learning_rate: 1.0000e-07
# Epoch 40/50
#
# Epoch 40: val_loss did not improve from 0.00000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-07
# Epoch 41/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9274 - loss: 0.1749
# Epoch 41: val_loss did not improve from 0.00000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 162s 5s/step - accuracy: 0.9274 - loss: 0.1749 - val_accuracy: 0.9208 - val_loss: 0.1921 - learning_rate: 1.0000e-07
# Epoch 42/50
#
# Epoch 42: val_loss did not improve from 0.00000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-07
# Epoch 43/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9304 - loss: 0.1695
# Epoch 43: val_loss did not improve from 0.00000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 160s 5s/step - accuracy: 0.9303 - loss: 0.1697 - val_accuracy: 0.9225 - val_loss: 0.1874 - learning_rate: 1.0000e-07
# Epoch 44/50
#
# Epoch 44: val_loss did not improve from 0.00000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-07
# Epoch 45/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9269 - loss: 0.1784
# Epoch 45: val_loss did not improve from 0.00000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 249s 8s/step - accuracy: 0.9269 - loss: 0.1783 - val_accuracy: 0.9237 - val_loss: 0.1848 - learning_rate: 1.0000e-07
# Epoch 46/50
#
# Epoch 46: val_loss did not improve from 0.00000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-07
# Epoch 47/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9294 - loss: 0.1703
# Epoch 47: val_loss did not improve from 0.00000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 156s 5s/step - accuracy: 0.9294 - loss: 0.1704 - val_accuracy: 0.9244 - val_loss: 0.1831 - learning_rate: 1.0000e-07
# Epoch 48/50
#
# Epoch 48: val_loss did not improve from 0.00000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-07
# Epoch 49/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9269 - loss: 0.1762
# Epoch 49: val_loss did not improve from 0.00000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 155s 5s/step - accuracy: 0.9270 - loss: 0.1762 - val_accuracy: 0.9247 - val_loss: 0.1822 - learning_rate: 1.0000e-07
# Epoch 50/50
#
# Epoch 50: val_loss did not improve from 0.00000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 863us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-07

# %%
import cv2

model = tf.keras.models.load_model("../test/unet-cnn.keras")

width = 256
height = 256

imgpath = "../dataset/xpm_annotate/images/0001.png"
img = cv2.imread(imgpath)
img2 = cv2.resize(img, (width, height))
img2 = img2/255.0
img3 = np.expand_dims(img2, axis=0)

pred = model.predict(img3)
resultMask = pred[0]

print(resultMask)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# [[[0.52401143]
#   [0.52835476]
#   [0.52950084]
#   ...
#   [0.51894605]
#   [0.5167547 ]
#   [0.5198737 ]]
#
#  [[0.52520484]
#   [0.5260088 ]
#   [0.52941585]
#   ...
#   [0.51295775]
#   [0.5227168 ]
#   [0.5179724 ]]
#
#  [[0.52132535]
#   [0.529012  ]
#   [0.5356832 ]
#   ...
#   [0.5180496 ]
#   [0.52668893]
#   [0.5289698 ]]
#
#  ...
#
#  [[0.5181293 ]
#   [0.49581283]
#   [0.497673  ]
#   ...
#   [0.48283303]
#   [0.4955786 ]
#   [0.5097421 ]]
#
#  [[0.5175083 ]
#   [0.507305  ]
#   [0.5020215 ]
#   ...
#   [0.49030027]
#   [0.49771458]
#   [0.51840407]]
#
#  [[0.511126  ]
#   [0.5070233 ]
#   [0.5134216 ]
#   ...
#   [0.49741113]
#   [0.5024809 ]
#   [0.5124818 ]]]

# %%
resultMask[resultMask <=0.5] = 0
resultMask[resultMask > 0.5] = 255

scale_percent = 30

w = int(img.shape[1] * scale_percent/100)
h = int(img.shape[0] * scale_percent/100)

dim = (w,h)

img = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
mask = cv2.resize(resultMask, dim, interpolation = cv2.INTER_AREA)

cv2.imshow("image", img)
cv2.imshow("mask", mask)
cv2.waitKey(0)
# Out:
# -1
