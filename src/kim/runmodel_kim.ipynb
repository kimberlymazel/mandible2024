# %% [markdown]
# ## U-Net Test

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model

model_path = "../../models/unetpp_model.h5"
model = load_model(model_path)
# Out:
# WARNING:tensorflow:From c:\Users\kimbe\anaconda3\envs\myenv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\Users\kimbe\anaconda3\envs\myenv\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\kimbe\anaconda3\envs\myenv\lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.

# %%
import cv2
import numpy as np
import os

# Create output directory if it doesn't exist
input_dir = '../../dataset/tinonewpano'
output_dir = '../../dataset/predicted'
os.makedirs(output_dir, exist_ok=True)

# List of image paths
filenames = os.listdir(input_dir)
image_paths = [os.path.join(input_dir, filename) for filename in filenames]

# Parameters
target_size = (128, 128)

def resize_and_pad(img, target_size):
    h, w = img.shape[:2]
    scale = min(target_size[0] / h, target_size[1] / w)
    new_w, new_h = int(w * scale), int(h * scale)
    resized_img = cv2.resize(img, (new_w, new_h))

    top = (target_size[0] - new_h) // 2
    bottom = target_size[0] - new_h - top
    left = (target_size[1] - new_w) // 2
    right = target_size[1] - new_w - left

    padded_img = cv2.copyMakeBorder(resized_img, top, bottom, left, right, cv2.BORDER_CONSTANT, value=[0, 0, 0])
    return padded_img, scale, (top, bottom, left, right)

def remove_padding_and_resize(mask, original_size, padding_info, scale):
    top, bottom, left, right = padding_info
    mask_cropped = mask[top:mask.shape[0]-bottom, left:mask.shape[1]-right]
    mask_resized = cv2.resize(mask_cropped, original_size, interpolation=cv2.INTER_LINEAR)
    return mask_resized

def apply_morphological_operations(mask):
    kernel = np.ones((5, 5), np.uint8)
    mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)
    mask = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel)
    return mask

for image_path in image_paths:
    # Read the image
    img = cv2.imread(image_path)
    if img is None:
        print(f"Error: Image {image_path} not found or cannot be read.")
        continue

    original_size = (img.shape[1], img.shape[0])

    # Resize and pad the image
    img_resized_padded, scale, padding_info = resize_and_pad(img, target_size)
    img_resized_padded = img_resized_padded / 255.0
    img_resized_padded = np.expand_dims(img_resized_padded, axis=0)

    # Predict the mask
    pred = model.predict(img_resized_padded)
    resultMask = pred[0]

    # Apply threshold
    resultMask[resultMask <= 0.5] = 0
    resultMask[resultMask > 0.5] = 255

    # Convert the mask to uint8 type before resizing
    resultMask = resultMask.astype(np.uint8)

    # Remove padding and resize the mask to the original image dimensions
    resultMask_resized = remove_padding_and_resize(resultMask, original_size, padding_info, scale)

    # Apply morphological operations to smooth the edges
    resultMask_smooth = apply_morphological_operations(resultMask_resized)

    # Apply stronger Gaussian blur to the resized mask
    resultMask_smooth = cv2.GaussianBlur(resultMask_smooth, (301, 301), 0)

    resultMask_smooth[resultMask_smooth <= 127.5] = 0
    resultMask_smooth[resultMask_smooth > 127.5] = 255

    # Save the mask as a TIFF file
    output_path = os.path.join(output_dir, f"{os.path.basename(image_path).split('.')[0]}_prediction.tiff")
    cv2.imwrite(output_path, resultMask_smooth)
    print(f"Saved mask to {output_path}")
# Out:
# 1/1 [==============================] - 0s 271ms/step
# Saved mask to ../../dataset/predicted\0104830_prediction.tiff
# 1/1 [==============================] - 0s 239ms/step
# Saved mask to ../../dataset/predicted\0105800_prediction.tiff
# 1/1 [==============================] - 0s 235ms/step
# Saved mask to ../../dataset/predicted\0312829_prediction.tiff
# 1/1 [==============================] - 0s 248ms/step
# Saved mask to ../../dataset/predicted\0404134_prediction.tiff
# 1/1 [==============================] - 0s 237ms/step
# Saved mask to ../../dataset/predicted\0412558_prediction.tiff
# 1/1 [==============================] - 0s 255ms/step
# Saved mask to ../../dataset/predicted\0510536_prediction.tiff
# 1/1 [==============================] - 0s 223ms/step
# Saved mask to ../../dataset/predicted\0614729_prediction.tiff
# 1/1 [==============================] - 0s 215ms/step
# Saved mask to ../../dataset/predicted\0800229_prediction.tiff
# 1/1 [==============================] - 0s 210ms/step
# Saved mask to ../../dataset/predicted\0805784_prediction.tiff
# 1/1 [==============================] - 0s 237ms/step
# Saved mask to ../../dataset/predicted\0807125_prediction.tiff
# 1/1 [==============================] - 0s 218ms/step
# Saved mask to ../../dataset/predicted\0811613_prediction.tiff
# 1/1 [==============================] - 0s 217ms/step
# Saved mask to ../../dataset/predicted\0814477_prediction.tiff
# 1/1 [==============================] - 0s 253ms/step
# Saved mask to ../../dataset/predicted\0900947_prediction.tiff
# 1/1 [==============================] - 0s 223ms/step
# Saved mask to ../../dataset/predicted\0911314_prediction.tiff
# 1/1 [==============================] - 0s 193ms/step
# Saved mask to ../../dataset/predicted\0914213_prediction.tiff
# 1/1 [==============================] - 0s 255ms/step
# Saved mask to ../../dataset/predicted\0914357_prediction.tiff
# 1/1 [==============================] - 0s 239ms/step
# Saved mask to ../../dataset/predicted\0914608_prediction.tiff
# 1/1 [==============================] - 0s 220ms/step
# Saved mask to ../../dataset/predicted\0915531_prediction.tiff
# 1/1 [==============================] - 0s 251ms/step
# Saved mask to ../../dataset/predicted\0915795_prediction.tiff
# 1/1 [==============================] - 0s 210ms/step
# Saved mask to ../../dataset/predicted\0916329_prediction.tiff
# 1/1 [==============================] - 0s 209ms/step
# Saved mask to ../../dataset/predicted\0916581_prediction.tiff
# 1/1 [==============================] - 0s 234ms/step
# Saved mask to ../../dataset/predicted\0916734_prediction.tiff
# 1/1 [==============================] - 0s 230ms/step
# Saved mask to ../../dataset/predicted\0917888_prediction.tiff
# 1/1 [==============================] - 0s 215ms/step
# Saved mask to ../../dataset/predicted\0918783_prediction.tiff
# 1/1 [==============================] - 0s 235ms/step
# Saved mask to ../../dataset/predicted\0920980_prediction.tiff
# 1/1 [==============================] - 0s 212ms/step
# Saved mask to ../../dataset/predicted\1000372_prediction.tiff
# 1/1 [==============================] - 0s 222ms/step
# Saved mask to ../../dataset/predicted\1000453_prediction.tiff
# 1/1 [==============================] - 0s 208ms/step
# Saved mask to ../../dataset/predicted\1002001_prediction.tiff
# 1/1 [==============================] - 0s 256ms/step
# Saved mask to ../../dataset/predicted\1002147_prediction.tiff
# 1/1 [==============================] - 0s 227ms/step
# Saved mask to ../../dataset/predicted\1002438_prediction.tiff
# 1/1 [==============================] - 0s 224ms/step
# Saved mask to ../../dataset/predicted\1002596_prediction.tiff
# 1/1 [==============================] - 0s 274ms/step
# Saved mask to ../../dataset/predicted\1003093_prediction.tiff
# 1/1 [==============================] - 0s 215ms/step
# Saved mask to ../../dataset/predicted\1004019_prediction.tiff
# 1/1 [==============================] - 0s 287ms/step
# Saved mask to ../../dataset/predicted\1004992_prediction.tiff
# 1/1 [==============================] - 0s 216ms/step
# Saved mask to ../../dataset/predicted\1005506_prediction.tiff
# 1/1 [==============================] - 0s 220ms/step
# Saved mask to ../../dataset/predicted\1005697_prediction.tiff
# 1/1 [==============================] - 0s 293ms/step
# Saved mask to ../../dataset/predicted\1006657_prediction.tiff
# 1/1 [==============================] - 0s 240ms/step
# Saved mask to ../../dataset/predicted\1006918_prediction.tiff
# 1/1 [==============================] - 0s 226ms/step
# Saved mask to ../../dataset/predicted\1007076_prediction.tiff
# 1/1 [==============================] - 0s 218ms/step
# Saved mask to ../../dataset/predicted\1007976_prediction.tiff
# 1/1 [==============================] - 0s 221ms/step
# Saved mask to ../../dataset/predicted\1008243_prediction.tiff
# 1/1 [==============================] - 0s 219ms/step
# Saved mask to ../../dataset/predicted\1008725_prediction.tiff
# 1/1 [==============================] - 0s 224ms/step
# Saved mask to ../../dataset/predicted\1009323_prediction.tiff
# 1/1 [==============================] - 0s 224ms/step
# Saved mask to ../../dataset/predicted\1009398_prediction.tiff
# 1/1 [==============================] - 0s 229ms/step
# Saved mask to ../../dataset/predicted\1009436_prediction.tiff
# 1/1 [==============================] - 0s 235ms/step
# Saved mask to ../../dataset/predicted\1013754_prediction.tiff
# 1/1 [==============================] - 0s 231ms/step
# Saved mask to ../../dataset/predicted\1015371_prediction.tiff
# 1/1 [==============================] - 0s 256ms/step
# Saved mask to ../../dataset/predicted\1401110_prediction.tiff
# 1/1 [==============================] - 0s 313ms/step
# Saved mask to ../../dataset/predicted\1401119_prediction.tiff
# 1/1 [==============================] - 0s 266ms/step
# Saved mask to ../../dataset/predicted\1401542_prediction.tiff
# 1/1 [==============================] - 0s 262ms/step
# Saved mask to ../../dataset/predicted\1404598_prediction.tiff
# 1/1 [==============================] - 0s 250ms/step
# Saved mask to ../../dataset/predicted\1404726_prediction.tiff
# 1/1 [==============================] - 0s 239ms/step
# Saved mask to ../../dataset/predicted\1405496_prediction.tiff
# 1/1 [==============================] - 0s 218ms/step
# Saved mask to ../../dataset/predicted\1405907_prediction.tiff
# 1/1 [==============================] - 0s 225ms/step
# Saved mask to ../../dataset/predicted\1405908_prediction.tiff
# 1/1 [==============================] - 0s 233ms/step
# Saved mask to ../../dataset/predicted\1406507_prediction.tiff
# 1/1 [==============================] - 0s 231ms/step
# Saved mask to ../../dataset/predicted\1408955_prediction.tiff
# 1/1 [==============================] - 0s 227ms/step
# Saved mask to ../../dataset/predicted\1409241_prediction.tiff
# 1/1 [==============================] - 0s 215ms/step
# Saved mask to ../../dataset/predicted\1409828_prediction.tiff
# 1/1 [==============================] - 0s 213ms/step
# Saved mask to ../../dataset/predicted\1410374_prediction.tiff
# 1/1 [==============================] - 0s 216ms/step
# Saved mask to ../../dataset/predicted\1410731_prediction.tiff
# 1/1 [==============================] - 0s 219ms/step
# Saved mask to ../../dataset/predicted\1411102_prediction.tiff
# 1/1 [==============================] - 0s 210ms/step
# Saved mask to ../../dataset/predicted\1411760_prediction.tiff
# 1/1 [==============================] - 0s 199ms/step
# Saved mask to ../../dataset/predicted\1500536_prediction.tiff
# 1/1 [==============================] - 0s 206ms/step
# Saved mask to ../../dataset/predicted\1500679_prediction.tiff
# 1/1 [==============================] - 0s 211ms/step
# Saved mask to ../../dataset/predicted\1501609_prediction.tiff
# 1/1 [==============================] - 0s 210ms/step
# Saved mask to ../../dataset/predicted\1501760_prediction.tiff
# 1/1 [==============================] - 0s 209ms/step
# Saved mask to ../../dataset/predicted\1503294_prediction.tiff
# 1/1 [==============================] - 0s 223ms/step
# Saved mask to ../../dataset/predicted\1503897_prediction.tiff
# 1/1 [==============================] - 0s 236ms/step
# Saved mask to ../../dataset/predicted\1506193_prediction.tiff
# 1/1 [==============================] - 0s 214ms/step
# Saved mask to ../../dataset/predicted\1506266_prediction.tiff
# 1/1 [==============================] - 0s 212ms/step
# Saved mask to ../../dataset/predicted\1506978_prediction.tiff
# 1/1 [==============================] - 0s 210ms/step
# Saved mask to ../../dataset/predicted\1508969_prediction.tiff
# 1/1 [==============================] - 0s 211ms/step
# Saved mask to ../../dataset/predicted\1509454_prediction.tiff
# 1/1 [==============================] - 0s 224ms/step
# Saved mask to ../../dataset/predicted\1509871_prediction.tiff
# 1/1 [==============================] - 0s 213ms/step
# Saved mask to ../../dataset/predicted\1509902_prediction.tiff
# 1/1 [==============================] - 0s 218ms/step
# Saved mask to ../../dataset/predicted\1510316_prediction.tiff
# 1/1 [==============================] - 0s 223ms/step
# Saved mask to ../../dataset/predicted\1515336_prediction.tiff
# 1/1 [==============================] - 0s 224ms/step
# Saved mask to ../../dataset/predicted\1516429_prediction.tiff
# 1/1 [==============================] - 0s 217ms/step
# Saved mask to ../../dataset/predicted\1517768_prediction.tiff
