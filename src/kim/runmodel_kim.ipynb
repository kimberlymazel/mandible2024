# %% [markdown]
# ## U-Net Test

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model

model_path = "../../models/unetpp_model.h5"
model = load_model(model_path)
# Out:
# WARNING:tensorflow:From c:\Users\kimbe\anaconda3\envs\myenv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\Users\kimbe\anaconda3\envs\myenv\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\kimbe\anaconda3\envs\myenv\lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.

# %%
import cv2
import numpy as np
import os

# Create output directory if it doesn't exist
input_dir = '../../forvin/measure'
output_dir = '../../forvin/predicted'
os.makedirs(output_dir, exist_ok=True)

# List of image paths
filenames = os.listdir(input_dir)
image_paths = [os.path.join(input_dir, filename) for filename in filenames]

# Parameters
target_size = (128, 128)

def resize_and_pad(img, target_size):
    h, w = img.shape[:2]
    scale = min(target_size[0] / h, target_size[1] / w)
    new_w, new_h = int(w * scale), int(h * scale)
    resized_img = cv2.resize(img, (new_w, new_h))

    top = (target_size[0] - new_h) // 2
    bottom = target_size[0] - new_h - top
    left = (target_size[1] - new_w) // 2
    right = target_size[1] - new_w - left

    padded_img = cv2.copyMakeBorder(resized_img, top, bottom, left, right, cv2.BORDER_CONSTANT, value=[0, 0, 0])
    return padded_img, scale, (top, bottom, left, right)

def remove_padding_and_resize(mask, original_size, padding_info, scale):
    top, bottom, left, right = padding_info
    mask_cropped = mask[top:mask.shape[0]-bottom, left:mask.shape[1]-right]
    mask_resized = cv2.resize(mask_cropped, original_size, interpolation=cv2.INTER_LINEAR)
    return mask_resized

def apply_morphological_operations(mask):
    kernel = np.ones((5, 5), np.uint8)
    mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)
    mask = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel)
    return mask

for image_path in image_paths:
    # Read the image
    img = cv2.imread(image_path)
    if img is None:
        print(f"Error: Image {image_path} not found or cannot be read.")
        continue

    original_size = (img.shape[1], img.shape[0])

    # Resize and pad the image
    img_resized_padded, scale, padding_info = resize_and_pad(img, target_size)
    img_resized_padded = img_resized_padded / 255.0
    img_resized_padded = np.expand_dims(img_resized_padded, axis=0)

    # Predict the mask
    pred = model.predict(img_resized_padded)
    resultMask = pred[0]

    # Apply threshold
    resultMask[resultMask <= 0.5] = 0
    resultMask[resultMask > 0.5] = 255

    # Convert the mask to uint8 type before resizing
    resultMask = resultMask.astype(np.uint8)

    # Remove padding and resize the mask to the original image dimensions
    resultMask_resized = remove_padding_and_resize(resultMask, original_size, padding_info, scale)

    # Apply morphological operations to smooth the edges
    resultMask_smooth = apply_morphological_operations(resultMask_resized)

    # Apply stronger Gaussian blur to the resized mask
    resultMask_smooth = cv2.GaussianBlur(resultMask_smooth, (301, 301), 0)

    resultMask_smooth[resultMask_smooth <= 127.5] = 0
    resultMask_smooth[resultMask_smooth > 127.5] = 255

    # Save the mask as a TIFF file
    output_path = os.path.join(output_dir, f"{os.path.basename(image_path).split('.')[0]}_prediction.tiff")
    cv2.imwrite(output_path, resultMask_smooth)
    print(f"Saved mask to {output_path}")
# Out:
# 1/1 [==============================] - 1s 945ms/step
# Saved mask to ../../forvin/predicted\0103924_prediction.tiff
# 1/1 [==============================] - 0s 252ms/step
# Saved mask to ../../forvin/predicted\0104607_prediction.tiff
# 1/1 [==============================] - 0s 229ms/step
# Saved mask to ../../forvin/predicted\0104830_prediction.tiff
# 1/1 [==============================] - 0s 238ms/step
# Saved mask to ../../forvin/predicted\0105800_prediction.tiff
# 1/1 [==============================] - 0s 260ms/step
# Saved mask to ../../forvin/predicted\0206378_prediction.tiff
# 1/1 [==============================] - 0s 208ms/step
# Saved mask to ../../forvin/predicted\0312829_prediction.tiff
# 1/1 [==============================] - 0s 233ms/step
# Saved mask to ../../forvin/predicted\0404134_prediction.tiff
# 1/1 [==============================] - 0s 233ms/step
# Saved mask to ../../forvin/predicted\0412558_prediction.tiff
# 1/1 [==============================] - 0s 247ms/step
# Saved mask to ../../forvin/predicted\0413594_prediction.tiff
# 1/1 [==============================] - 0s 253ms/step
# Saved mask to ../../forvin/predicted\0510536_prediction.tiff
# 1/1 [==============================] - 0s 275ms/step
# Saved mask to ../../forvin/predicted\0613818_prediction.tiff
# 1/1 [==============================] - 0s 238ms/step
# Saved mask to ../../forvin/predicted\0614729_prediction.tiff
# 1/1 [==============================] - 0s 318ms/step
# Saved mask to ../../forvin/predicted\0701332_prediction.tiff
# 1/1 [==============================] - 0s 217ms/step
# Saved mask to ../../forvin/predicted\0708439_prediction.tiff
# 1/1 [==============================] - 0s 220ms/step
# Saved mask to ../../forvin/predicted\0714572_prediction.tiff
# 1/1 [==============================] - 0s 287ms/step
# Saved mask to ../../forvin/predicted\0800229_prediction.tiff
# 1/1 [==============================] - 0s 245ms/step
# Saved mask to ../../forvin/predicted\0805784_prediction.tiff
# 1/1 [==============================] - 0s 238ms/step
# Saved mask to ../../forvin/predicted\0807125_prediction.tiff
# 1/1 [==============================] - 0s 211ms/step
# Saved mask to ../../forvin/predicted\0808121_prediction.tiff
# 1/1 [==============================] - 0s 262ms/step
# Saved mask to ../../forvin/predicted\0810504_prediction.tiff
# 1/1 [==============================] - 0s 299ms/step
# Saved mask to ../../forvin/predicted\0811613_prediction.tiff
# 1/1 [==============================] - 0s 225ms/step
# Saved mask to ../../forvin/predicted\0814472_prediction.tiff
# 1/1 [==============================] - 0s 218ms/step
# Saved mask to ../../forvin/predicted\0814477_prediction.tiff
# 1/1 [==============================] - 0s 216ms/step
# Saved mask to ../../forvin/predicted\0900476_prediction.tiff
# 1/1 [==============================] - 0s 208ms/step
# Saved mask to ../../forvin/predicted\0900947_prediction.tiff
# 1/1 [==============================] - 0s 215ms/step
# Saved mask to ../../forvin/predicted\0904295_prediction.tiff
# 1/1 [==============================] - 0s 216ms/step
# Saved mask to ../../forvin/predicted\0911314_prediction.tiff
# 1/1 [==============================] - 0s 203ms/step
# Saved mask to ../../forvin/predicted\0914213_prediction.tiff
# 1/1 [==============================] - 0s 217ms/step
# Saved mask to ../../forvin/predicted\0914357_prediction.tiff
# 1/1 [==============================] - 0s 215ms/step
# Saved mask to ../../forvin/predicted\0914608_prediction.tiff
# 1/1 [==============================] - 0s 216ms/step
# Saved mask to ../../forvin/predicted\0915531_prediction.tiff
# 1/1 [==============================] - 0s 210ms/step
# Saved mask to ../../forvin/predicted\0915795_prediction.tiff
# 1/1 [==============================] - 0s 220ms/step
# Saved mask to ../../forvin/predicted\0916329_prediction.tiff
# 1/1 [==============================] - 0s 215ms/step
# Saved mask to ../../forvin/predicted\0916581_prediction.tiff
# 1/1 [==============================] - 0s 218ms/step
# Saved mask to ../../forvin/predicted\0916734_prediction.tiff
# 1/1 [==============================] - 0s 250ms/step
# Saved mask to ../../forvin/predicted\0916815_prediction.tiff
# 1/1 [==============================] - 0s 206ms/step
# Saved mask to ../../forvin/predicted\0917888_prediction.tiff
# 1/1 [==============================] - 0s 203ms/step
# Saved mask to ../../forvin/predicted\0918783_prediction.tiff
# 1/1 [==============================] - 0s 211ms/step
# Saved mask to ../../forvin/predicted\0920980_prediction.tiff
# 1/1 [==============================] - 0s 258ms/step
# Saved mask to ../../forvin/predicted\1000372_prediction.tiff
# 1/1 [==============================] - 0s 256ms/step
# Saved mask to ../../forvin/predicted\1000453_prediction.tiff
# 1/1 [==============================] - 0s 248ms/step
# Saved mask to ../../forvin/predicted\1000619_prediction.tiff
# 1/1 [==============================] - 0s 246ms/step
# Saved mask to ../../forvin/predicted\1002001_prediction.tiff
# 1/1 [==============================] - 0s 217ms/step
# Saved mask to ../../forvin/predicted\1002147_prediction.tiff
# 1/1 [==============================] - 0s 268ms/step
# Saved mask to ../../forvin/predicted\1002438_prediction.tiff
# 1/1 [==============================] - 0s 238ms/step
# Saved mask to ../../forvin/predicted\1002596_prediction.tiff
# 1/1 [==============================] - 0s 250ms/step
# Saved mask to ../../forvin/predicted\1003093_prediction.tiff
# 1/1 [==============================] - 0s 230ms/step
# Saved mask to ../../forvin/predicted\1004019_prediction.tiff
# 1/1 [==============================] - 0s 243ms/step
# Saved mask to ../../forvin/predicted\1004992_prediction.tiff
# 1/1 [==============================] - 0s 236ms/step
# Saved mask to ../../forvin/predicted\1005506_prediction.tiff
# 1/1 [==============================] - 0s 284ms/step
# Saved mask to ../../forvin/predicted\1005697_prediction.tiff
# 1/1 [==============================] - 0s 253ms/step
# Saved mask to ../../forvin/predicted\1006657_prediction.tiff
# 1/1 [==============================] - 0s 242ms/step
# Saved mask to ../../forvin/predicted\1006918_prediction.tiff
# 1/1 [==============================] - 0s 265ms/step
# Saved mask to ../../forvin/predicted\1007076_prediction.tiff
# 1/1 [==============================] - 0s 250ms/step
# Saved mask to ../../forvin/predicted\1007976_prediction.tiff
# 1/1 [==============================] - 0s 240ms/step
# Saved mask to ../../forvin/predicted\1008243_prediction.tiff
# 1/1 [==============================] - 0s 246ms/step
# Saved mask to ../../forvin/predicted\1008725_prediction.tiff
# 1/1 [==============================] - 0s 254ms/step
# Saved mask to ../../forvin/predicted\1008906_prediction.tiff
# 1/1 [==============================] - 0s 277ms/step
# Saved mask to ../../forvin/predicted\1009323_prediction.tiff
# 1/1 [==============================] - 0s 211ms/step
# Saved mask to ../../forvin/predicted\1009398_prediction.tiff
# 1/1 [==============================] - 0s 224ms/step
# Saved mask to ../../forvin/predicted\1009436_prediction.tiff
# 1/1 [==============================] - 0s 210ms/step
# Saved mask to ../../forvin/predicted\1013754_prediction.tiff
# 1/1 [==============================] - 0s 217ms/step
# Saved mask to ../../forvin/predicted\1015371_prediction.tiff
# 1/1 [==============================] - 0s 320ms/step
# Saved mask to ../../forvin/predicted\1401110_prediction.tiff
# 1/1 [==============================] - 0s 225ms/step
# Saved mask to ../../forvin/predicted\1401119_prediction.tiff
# 1/1 [==============================] - 0s 246ms/step
# Saved mask to ../../forvin/predicted\1401542_prediction.tiff
# 1/1 [==============================] - 0s 230ms/step
# Saved mask to ../../forvin/predicted\1404021_prediction.tiff
# 1/1 [==============================] - 0s 268ms/step
# Saved mask to ../../forvin/predicted\1404598_prediction.tiff
# 1/1 [==============================] - 0s 269ms/step
# Saved mask to ../../forvin/predicted\1404726_prediction.tiff
# 1/1 [==============================] - 0s 199ms/step
# Saved mask to ../../forvin/predicted\1405496_prediction.tiff
# 1/1 [==============================] - 0s 212ms/step
# Saved mask to ../../forvin/predicted\1405907_prediction.tiff
# 1/1 [==============================] - 0s 207ms/step
# Saved mask to ../../forvin/predicted\1405908_prediction.tiff
# 1/1 [==============================] - 0s 208ms/step
# Saved mask to ../../forvin/predicted\1405973_prediction.tiff
# 1/1 [==============================] - 0s 215ms/step
# Saved mask to ../../forvin/predicted\1406507_prediction.tiff
# 1/1 [==============================] - 0s 208ms/step
# Saved mask to ../../forvin/predicted\1408955_prediction.tiff
# 1/1 [==============================] - 0s 234ms/step
# Saved mask to ../../forvin/predicted\1409241_prediction.tiff
# 1/1 [==============================] - 0s 260ms/step
# Saved mask to ../../forvin/predicted\1409435_prediction.tiff
# 1/1 [==============================] - 0s 222ms/step
# Saved mask to ../../forvin/predicted\1409828_prediction.tiff
# 1/1 [==============================] - 0s 206ms/step
# Saved mask to ../../forvin/predicted\1410374_prediction.tiff
# 1/1 [==============================] - 0s 223ms/step
# Saved mask to ../../forvin/predicted\1410731_prediction.tiff
# 1/1 [==============================] - 0s 233ms/step
# Saved mask to ../../forvin/predicted\1411102_prediction.tiff
# 1/1 [==============================] - 0s 217ms/step
# Saved mask to ../../forvin/predicted\1411760_prediction.tiff
# 1/1 [==============================] - 0s 212ms/step
# Saved mask to ../../forvin/predicted\1500536_prediction.tiff
# 1/1 [==============================] - 0s 225ms/step
# Saved mask to ../../forvin/predicted\1500679_prediction.tiff
# 1/1 [==============================] - 0s 254ms/step
# Saved mask to ../../forvin/predicted\1501609_prediction.tiff
# 1/1 [==============================] - 0s 235ms/step
# Saved mask to ../../forvin/predicted\1501760_prediction.tiff
# 1/1 [==============================] - 0s 224ms/step
# Saved mask to ../../forvin/predicted\1503294_prediction.tiff
# 1/1 [==============================] - 0s 208ms/step
# Saved mask to ../../forvin/predicted\1503378_prediction.tiff
# 1/1 [==============================] - 0s 253ms/step
# Saved mask to ../../forvin/predicted\1503897_prediction.tiff
# 1/1 [==============================] - 0s 286ms/step
# Saved mask to ../../forvin/predicted\1506193_prediction.tiff
# 1/1 [==============================] - 0s 211ms/step
# Saved mask to ../../forvin/predicted\1506266_prediction.tiff
# 1/1 [==============================] - 0s 214ms/step
# Saved mask to ../../forvin/predicted\1506343_prediction.tiff
# 1/1 [==============================] - 0s 240ms/step
# Saved mask to ../../forvin/predicted\1506536_prediction.tiff
# 1/1 [==============================] - 0s 201ms/step
# Saved mask to ../../forvin/predicted\1506978_prediction.tiff
# 1/1 [==============================] - 0s 237ms/step
# Saved mask to ../../forvin/predicted\1507529_prediction.tiff
# 1/1 [==============================] - 0s 220ms/step
# Saved mask to ../../forvin/predicted\1508098_prediction.tiff
# 1/1 [==============================] - 0s 234ms/step
# Saved mask to ../../forvin/predicted\1508936_prediction.tiff
# 1/1 [==============================] - 0s 245ms/step
# Saved mask to ../../forvin/predicted\1508969_prediction.tiff
# 1/1 [==============================] - 0s 236ms/step
# Saved mask to ../../forvin/predicted\1509454_prediction.tiff
# 1/1 [==============================] - 0s 205ms/step
# Saved mask to ../../forvin/predicted\1509479_prediction.tiff
# 1/1 [==============================] - 0s 205ms/step
# Saved mask to ../../forvin/predicted\1509616_prediction.tiff
# 1/1 [==============================] - 0s 221ms/step
# Saved mask to ../../forvin/predicted\1509871_prediction.tiff
# 1/1 [==============================] - 0s 212ms/step
# Saved mask to ../../forvin/predicted\1509902_prediction.tiff
# 1/1 [==============================] - 0s 223ms/step
# Saved mask to ../../forvin/predicted\1509982_prediction.tiff
# 1/1 [==============================] - 0s 219ms/step
# Saved mask to ../../forvin/predicted\1510316_prediction.tiff
# 1/1 [==============================] - 0s 224ms/step
# Saved mask to ../../forvin/predicted\1510422_prediction.tiff
# 1/1 [==============================] - 0s 224ms/step
# Saved mask to ../../forvin/predicted\1510488_prediction.tiff
# 1/1 [==============================] - 0s 226ms/step
# Saved mask to ../../forvin/predicted\1510906_prediction.tiff
# 1/1 [==============================] - 0s 216ms/step
# Saved mask to ../../forvin/predicted\1510921_prediction.tiff
# 1/1 [==============================] - 0s 276ms/step
# Saved mask to ../../forvin/predicted\1510985_prediction.tiff
# 1/1 [==============================] - 0s 230ms/step
# Saved mask to ../../forvin/predicted\1512125_prediction.tiff
# 1/1 [==============================] - 0s 223ms/step
# Saved mask to ../../forvin/predicted\1512246_prediction.tiff
# 1/1 [==============================] - 0s 215ms/step
# Saved mask to ../../forvin/predicted\1513314_prediction.tiff
# 1/1 [==============================] - 0s 207ms/step
# Saved mask to ../../forvin/predicted\1513522_prediction.tiff
# 1/1 [==============================] - 0s 224ms/step
# Saved mask to ../../forvin/predicted\1513551_prediction.tiff
# 1/1 [==============================] - 0s 221ms/step
# Saved mask to ../../forvin/predicted\1513682_prediction.tiff
# 1/1 [==============================] - 0s 207ms/step
# Saved mask to ../../forvin/predicted\1514519_prediction.tiff
# 1/1 [==============================] - 0s 235ms/step
# Saved mask to ../../forvin/predicted\1514834_prediction.tiff
# 1/1 [==============================] - 0s 239ms/step
# Saved mask to ../../forvin/predicted\1515336_prediction.tiff
# 1/1 [==============================] - 0s 212ms/step
# Saved mask to ../../forvin/predicted\1516429_prediction.tiff
# 1/1 [==============================] - 0s 214ms/step
# Saved mask to ../../forvin/predicted\1516578_prediction.tiff
# 1/1 [==============================] - 0s 228ms/step
# Saved mask to ../../forvin/predicted\1517089_prediction.tiff
# 1/1 [==============================] - 0s 223ms/step
# Saved mask to ../../forvin/predicted\1517768_prediction.tiff
# 1/1 [==============================] - 0s 226ms/step
# Saved mask to ../../forvin/predicted\1518809_prediction.tiff
# 1/1 [==============================] - 0s 218ms/step
# Saved mask to ../../forvin/predicted\1519630_prediction.tiff
# 1/1 [==============================] - 0s 207ms/step
# Saved mask to ../../forvin/predicted\1519932_prediction.tiff
# 1/1 [==============================] - 0s 220ms/step
# Saved mask to ../../forvin/predicted\1519954_prediction.tiff
# 1/1 [==============================] - 0s 246ms/step
# Saved mask to ../../forvin/predicted\1520943_prediction.tiff
# 1/1 [==============================] - 0s 230ms/step
# Saved mask to ../../forvin/predicted\1521480_prediction.tiff
# 1/1 [==============================] - 0s 229ms/step
# Saved mask to ../../forvin/predicted\1521723_prediction.tiff
# 1/1 [==============================] - 0s 220ms/step
# Saved mask to ../../forvin/predicted\1522129_prediction.tiff
# 1/1 [==============================] - 0s 262ms/step
# Saved mask to ../../forvin/predicted\1522701_prediction.tiff
# 1/1 [==============================] - 0s 229ms/step
# Saved mask to ../../forvin/predicted\1522727_prediction.tiff
# 1/1 [==============================] - 0s 208ms/step
# Saved mask to ../../forvin/predicted\1523119_prediction.tiff
# 1/1 [==============================] - 0s 221ms/step
# Saved mask to ../../forvin/predicted\1523762_prediction.tiff
# 1/1 [==============================] - 0s 223ms/step
# Saved mask to ../../forvin/predicted\1524858_prediction.tiff
# 1/1 [==============================] - 0s 242ms/step
# Saved mask to ../../forvin/predicted\1524995_prediction.tiff
# 1/1 [==============================] - 0s 266ms/step
# Saved mask to ../../forvin/predicted\1525630_prediction.tiff
# 1/1 [==============================] - 0s 231ms/step
# Saved mask to ../../forvin/predicted\1525969_prediction.tiff
# 1/1 [==============================] - 0s 235ms/step
# Saved mask to ../../forvin/predicted\1527767_prediction.tiff
# 1/1 [==============================] - 0s 282ms/step
# Saved mask to ../../forvin/predicted\1528093_prediction.tiff
# 1/1 [==============================] - 0s 257ms/step
# Saved mask to ../../forvin/predicted\1529684_prediction.tiff
# 1/1 [==============================] - 0s 226ms/step
# Saved mask to ../../forvin/predicted\1529952_prediction.tiff
# 1/1 [==============================] - 0s 220ms/step
# Saved mask to ../../forvin/predicted\1530332_prediction.tiff
# 1/1 [==============================] - 0s 217ms/step
# Saved mask to ../../forvin/predicted\1530518_prediction.tiff
# 1/1 [==============================] - 0s 255ms/step
# Saved mask to ../../forvin/predicted\1531440_prediction.tiff
# 1/1 [==============================] - 0s 220ms/step
# Saved mask to ../../forvin/predicted\1531939_prediction.tiff
# 1/1 [==============================] - 0s 214ms/step
# Saved mask to ../../forvin/predicted\1532000_prediction.tiff
# 1/1 [==============================] - 0s 223ms/step
# Saved mask to ../../forvin/predicted\1532374_prediction.tiff
# 1/1 [==============================] - 0s 222ms/step
# Saved mask to ../../forvin/predicted\1532720_prediction.tiff
# 1/1 [==============================] - 0s 265ms/step
# Saved mask to ../../forvin/predicted\1533261_prediction.tiff
# 1/1 [==============================] - 0s 221ms/step
# Saved mask to ../../forvin/predicted\1533292_prediction.tiff
# 1/1 [==============================] - 0s 203ms/step
# Saved mask to ../../forvin/predicted\1534292_prediction.tiff
# 1/1 [==============================] - 0s 208ms/step
# Saved mask to ../../forvin/predicted\1534478_prediction.tiff
# 1/1 [==============================] - 0s 204ms/step
# Saved mask to ../../forvin/predicted\1535989_prediction.tiff
# 1/1 [==============================] - 0s 221ms/step
# Saved mask to ../../forvin/predicted\1536656_prediction.tiff
# 1/1 [==============================] - 0s 198ms/step
# Saved mask to ../../forvin/predicted\1537090_prediction.tiff
# 1/1 [==============================] - 0s 210ms/step
# Saved mask to ../../forvin/predicted\1537362_prediction.tiff
# 1/1 [==============================] - 0s 211ms/step
# Saved mask to ../../forvin/predicted\1537775_prediction.tiff
# 1/1 [==============================] - 0s 207ms/step
# Saved mask to ../../forvin/predicted\1538136_prediction.tiff
# 1/1 [==============================] - 0s 223ms/step
# Saved mask to ../../forvin/predicted\1538693_prediction.tiff
# 1/1 [==============================] - 0s 210ms/step
# Saved mask to ../../forvin/predicted\1540018_prediction.tiff
# 1/1 [==============================] - 0s 213ms/step
# Saved mask to ../../forvin/predicted\1541349_prediction.tiff
# 1/1 [==============================] - 0s 295ms/step
# Saved mask to ../../forvin/predicted\1541606_prediction.tiff
# 1/1 [==============================] - 0s 249ms/step
# Saved mask to ../../forvin/predicted\1542643_prediction.tiff
# 1/1 [==============================] - 0s 218ms/step
# Saved mask to ../../forvin/predicted\1542668_prediction.tiff
# 1/1 [==============================] - 0s 293ms/step
# Saved mask to ../../forvin/predicted\1543894_prediction.tiff
# 1/1 [==============================] - 0s 304ms/step
# Saved mask to ../../forvin/predicted\1544360_prediction.tiff
# 1/1 [==============================] - 0s 262ms/step
# Saved mask to ../../forvin/predicted\1544460_prediction.tiff
# 1/1 [==============================] - 0s 240ms/step
# Saved mask to ../../forvin/predicted\1547612_prediction.tiff
# 1/1 [==============================] - 0s 236ms/step
# Saved mask to ../../forvin/predicted\1547776_prediction.tiff
# 1/1 [==============================] - 0s 252ms/step
# Saved mask to ../../forvin/predicted\1547854_prediction.tiff
# 1/1 [==============================] - 0s 229ms/step
# Saved mask to ../../forvin/predicted\1548023_prediction.tiff
# 1/1 [==============================] - 0s 237ms/step
# Saved mask to ../../forvin/predicted\1548210_prediction.tiff
# 1/1 [==============================] - 0s 217ms/step
# Saved mask to ../../forvin/predicted\1549068_prediction.tiff
# 1/1 [==============================] - 0s 251ms/step
# Saved mask to ../../forvin/predicted\1549108_prediction.tiff
# 1/1 [==============================] - 0s 243ms/step
# Saved mask to ../../forvin/predicted\1549208_prediction.tiff
# 1/1 [==============================] - 0s 242ms/step
# Saved mask to ../../forvin/predicted\1549644_prediction.tiff
# 1/1 [==============================] - 0s 244ms/step
# Saved mask to ../../forvin/predicted\1550382_prediction.tiff
# 1/1 [==============================] - 0s 239ms/step
# Saved mask to ../../forvin/predicted\1550539_prediction.tiff
# 1/1 [==============================] - 0s 238ms/step
# Saved mask to ../../forvin/predicted\1553560_prediction.tiff
# 1/1 [==============================] - 0s 263ms/step
# Saved mask to ../../forvin/predicted\1553863_prediction.tiff
# 1/1 [==============================] - 0s 241ms/step
# Saved mask to ../../forvin/predicted\1554936_prediction.tiff
# 1/1 [==============================] - 0s 265ms/step
# Saved mask to ../../forvin/predicted\1556803_prediction.tiff
# 1/1 [==============================] - 0s 246ms/step
# Saved mask to ../../forvin/predicted\1556882_prediction.tiff
# 1/1 [==============================] - 0s 237ms/step
# Saved mask to ../../forvin/predicted\1557282_prediction.tiff
# 1/1 [==============================] - 0s 244ms/step
# Saved mask to ../../forvin/predicted\1557408_prediction.tiff
# 1/1 [==============================] - 0s 287ms/step
# Saved mask to ../../forvin/predicted\1557839_prediction.tiff
# 1/1 [==============================] - 0s 322ms/step
# Saved mask to ../../forvin/predicted\1558579_prediction.tiff
# 1/1 [==============================] - 0s 241ms/step
# Saved mask to ../../forvin/predicted\1559028_prediction.tiff
# 1/1 [==============================] - 0s 248ms/step
# Saved mask to ../../forvin/predicted\1559216_prediction.tiff
# 1/1 [==============================] - 0s 250ms/step
# Saved mask to ../../forvin/predicted\1559875_prediction.tiff
# 1/1 [==============================] - 0s 244ms/step
# Saved mask to ../../forvin/predicted\1560065_prediction.tiff
# 1/1 [==============================] - 0s 237ms/step
# Saved mask to ../../forvin/predicted\1560290_prediction.tiff
# 1/1 [==============================] - 0s 250ms/step
# Saved mask to ../../forvin/predicted\1561379_prediction.tiff
# 1/1 [==============================] - 0s 264ms/step
# Saved mask to ../../forvin/predicted\1564350_prediction.tiff
# 1/1 [==============================] - 0s 231ms/step
# Saved mask to ../../forvin/predicted\1564734_prediction.tiff
# 1/1 [==============================] - 0s 246ms/step
# Saved mask to ../../forvin/predicted\1566382_prediction.tiff
# 1/1 [==============================] - 0s 211ms/step
# Saved mask to ../../forvin/predicted\1570391_prediction.tiff
# 1/1 [==============================] - 0s 241ms/step
# Saved mask to ../../forvin/predicted\909576_prediction.tiff
# 1/1 [==============================] - 0s 247ms/step
# Saved mask to ../../forvin/predicted\911876_prediction.tiff
