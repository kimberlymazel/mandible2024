# %% [markdown]
# ## U-Net Test

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model

model_path = "../../models/unetpp_model.h5"
model = load_model(model_path)
# Out:
# WARNING:tensorflow:From c:\Users\kimbe\anaconda3\envs\myenv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\Users\kimbe\anaconda3\envs\myenv\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\kimbe\anaconda3\envs\myenv\lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.

# %%
import cv2
import numpy as np
import os

# Create output directory if it doesn't exist
input_dir = '../../forvin/measure'
output_dir = '../../forvin/predictions'
os.makedirs(output_dir, exist_ok=True)

# List of image paths
filenames = os.listdir(input_dir)
image_paths = [os.path.join(input_dir, filename) for filename in filenames]

# Parameters
target_size = (128, 128)

def resize_and_pad(img, target_size):
    h, w = img.shape[:2]
    scale = min(target_size[0] / h, target_size[1] / w)
    new_w, new_h = int(w * scale), int(h * scale)
    resized_img = cv2.resize(img, (new_w, new_h))

    top = (target_size[0] - new_h) // 2
    bottom = target_size[0] - new_h - top
    left = (target_size[1] - new_w) // 2
    right = target_size[1] - new_w - left

    padded_img = cv2.copyMakeBorder(resized_img, top, bottom, left, right, cv2.BORDER_CONSTANT, value=[0, 0, 0])
    return padded_img, scale, (top, bottom, left, right)

def remove_padding_and_resize(mask, original_size, padding_info, scale):
    top, bottom, left, right = padding_info
    mask_cropped = mask[top:mask.shape[0]-bottom, left:mask.shape[1]-right]
    mask_resized = cv2.resize(mask_cropped, original_size, interpolation=cv2.INTER_LINEAR)
    return mask_resized

def apply_morphological_operations(mask):
    kernel = np.ones((5, 5), np.uint8)
    mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)
    mask = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel)
    return mask

for image_path in image_paths:
    # Read the image
    img = cv2.imread(image_path)
    if img is None:
        print(f"Error: Image {image_path} not found or cannot be read.")
        continue

    original_size = (img.shape[1], img.shape[0])

    # Resize and pad the image
    img_resized_padded, scale, padding_info = resize_and_pad(img, target_size)
    img_resized_padded = img_resized_padded / 255.0
    img_resized_padded = np.expand_dims(img_resized_padded, axis=0)

    # Predict the mask
    pred = model.predict(img_resized_padded)
    resultMask = pred[0]

    # Apply threshold
    resultMask[resultMask <= 0.5] = 0
    resultMask[resultMask > 0.5] = 255

    # Convert the mask to uint8 type before resizing
    resultMask = resultMask.astype(np.uint8)

    # Remove padding and resize the mask to the original image dimensions
    resultMask_resized = remove_padding_and_resize(resultMask, original_size, padding_info, scale)

    # Apply morphological operations to smooth the edges
    resultMask_smooth = apply_morphological_operations(resultMask_resized)

    # Apply stronger Gaussian blur to the resized mask
    resultMask_smooth = cv2.GaussianBlur(resultMask_smooth, (301, 301), 0)

    resultMask_smooth[resultMask_smooth <= 127.5] = 0
    resultMask_smooth[resultMask_smooth > 127.5] = 255

    # Save the mask as a TIFF file
    output_path = os.path.join(output_dir, f"{os.path.basename(image_path).split('.')[0]}_prediction.tiff")
    cv2.imwrite(output_path, resultMask_smooth)
    print(f"Saved mask to {output_path}")
# Out:
# 1/1 [==============================] - 2s 2s/step
# Saved mask to ../../forvin/predictions\0103924_prediction.tiff
# 1/1 [==============================] - 0s 409ms/step
# Saved mask to ../../forvin/predictions\0104607_prediction.tiff
# 1/1 [==============================] - 0s 434ms/step
# Saved mask to ../../forvin/predictions\0104830_prediction.tiff
# 1/1 [==============================] - 0s 369ms/step
# Saved mask to ../../forvin/predictions\0105800_prediction.tiff
# 1/1 [==============================] - 0s 365ms/step
# Saved mask to ../../forvin/predictions\0206378_prediction.tiff
# 1/1 [==============================] - 0s 361ms/step
# Saved mask to ../../forvin/predictions\0312829_prediction.tiff
# 1/1 [==============================] - 0s 322ms/step
# Saved mask to ../../forvin/predictions\0404134_prediction.tiff
# 1/1 [==============================] - 0s 341ms/step
# Saved mask to ../../forvin/predictions\0412558_prediction.tiff
# 1/1 [==============================] - 0s 408ms/step
# Saved mask to ../../forvin/predictions\0413594_prediction.tiff
# 1/1 [==============================] - 0s 371ms/step
# Saved mask to ../../forvin/predictions\0510536_prediction.tiff
# 1/1 [==============================] - 0s 500ms/step
# Saved mask to ../../forvin/predictions\0613818_prediction.tiff
# 1/1 [==============================] - 0s 429ms/step
# Saved mask to ../../forvin/predictions\0614729_prediction.tiff
# 1/1 [==============================] - 1s 548ms/step
# Saved mask to ../../forvin/predictions\0701332_prediction.tiff
# 1/1 [==============================] - 0s 409ms/step
# Saved mask to ../../forvin/predictions\0708439_prediction.tiff
# 1/1 [==============================] - 0s 357ms/step
# Saved mask to ../../forvin/predictions\0714572_prediction.tiff
# 1/1 [==============================] - 0s 358ms/step
# Saved mask to ../../forvin/predictions\0800229_prediction.tiff
# 1/1 [==============================] - 0s 399ms/step
# Saved mask to ../../forvin/predictions\0805784_prediction.tiff
# 1/1 [==============================] - 0s 399ms/step
# Saved mask to ../../forvin/predictions\0807125_prediction.tiff
# 1/1 [==============================] - 0s 335ms/step
# Saved mask to ../../forvin/predictions\0808121_prediction.tiff
# 1/1 [==============================] - 0s 325ms/step
# Saved mask to ../../forvin/predictions\0810504_prediction.tiff
# 1/1 [==============================] - 0s 364ms/step
# Saved mask to ../../forvin/predictions\0811613_prediction.tiff
# 1/1 [==============================] - 0s 342ms/step
# Saved mask to ../../forvin/predictions\0814472_prediction.tiff
# 1/1 [==============================] - 0s 323ms/step
# Saved mask to ../../forvin/predictions\0814477_prediction.tiff
# 1/1 [==============================] - 0s 364ms/step
# Saved mask to ../../forvin/predictions\0900476_prediction.tiff
# 1/1 [==============================] - 0s 350ms/step
# Saved mask to ../../forvin/predictions\0900947_prediction.tiff
# 1/1 [==============================] - 0s 375ms/step
# Saved mask to ../../forvin/predictions\0904295_prediction.tiff
# 1/1 [==============================] - 0s 338ms/step
# Saved mask to ../../forvin/predictions\0911314_prediction.tiff
# 1/1 [==============================] - 0s 303ms/step
# Saved mask to ../../forvin/predictions\0914213_prediction.tiff
# 1/1 [==============================] - 0s 318ms/step
# Saved mask to ../../forvin/predictions\0914357_prediction.tiff
# 1/1 [==============================] - 0s 302ms/step
# Saved mask to ../../forvin/predictions\0914608_prediction.tiff
# 1/1 [==============================] - 0s 310ms/step
# Saved mask to ../../forvin/predictions\0915531_prediction.tiff
# 1/1 [==============================] - 0s 353ms/step
# Saved mask to ../../forvin/predictions\0915795_prediction.tiff
# 1/1 [==============================] - 0s 359ms/step
# Saved mask to ../../forvin/predictions\0916329_prediction.tiff
# 1/1 [==============================] - 0s 415ms/step
# Saved mask to ../../forvin/predictions\0916581_prediction.tiff
# 1/1 [==============================] - 0s 499ms/step
# Saved mask to ../../forvin/predictions\0916734_prediction.tiff
# 1/1 [==============================] - 0s 419ms/step
# Saved mask to ../../forvin/predictions\0916815_prediction.tiff
# 1/1 [==============================] - 0s 441ms/step
# Saved mask to ../../forvin/predictions\0917888_prediction.tiff
# 1/1 [==============================] - 0s 458ms/step
# Saved mask to ../../forvin/predictions\0918783_prediction.tiff
# 1/1 [==============================] - 0s 470ms/step
# Saved mask to ../../forvin/predictions\0920980_prediction.tiff
# 1/1 [==============================] - 0s 426ms/step
# Saved mask to ../../forvin/predictions\1000372_prediction.tiff
# 1/1 [==============================] - 0s 428ms/step
# Saved mask to ../../forvin/predictions\1000453_prediction.tiff
# 1/1 [==============================] - 0s 440ms/step
# Saved mask to ../../forvin/predictions\1000619_prediction.tiff
# 1/1 [==============================] - 0s 438ms/step
# Saved mask to ../../forvin/predictions\1002001_prediction.tiff
# 1/1 [==============================] - 0s 451ms/step
# Saved mask to ../../forvin/predictions\1002147_prediction.tiff
# 1/1 [==============================] - 0s 415ms/step
# Saved mask to ../../forvin/predictions\1002438_prediction.tiff
# 1/1 [==============================] - 0s 413ms/step
# Saved mask to ../../forvin/predictions\1002596_prediction.tiff
# 1/1 [==============================] - 0s 479ms/step
# Saved mask to ../../forvin/predictions\1003093_prediction.tiff
# 1/1 [==============================] - 0s 458ms/step
# Saved mask to ../../forvin/predictions\1004019_prediction.tiff
# 1/1 [==============================] - 0s 477ms/step
# Saved mask to ../../forvin/predictions\1004992_prediction.tiff
# 1/1 [==============================] - 1s 512ms/step
# Saved mask to ../../forvin/predictions\1005506_prediction.tiff
# 1/1 [==============================] - 1s 542ms/step
# Saved mask to ../../forvin/predictions\1005697_prediction.tiff
# 1/1 [==============================] - 1s 508ms/step
# Saved mask to ../../forvin/predictions\1006657_prediction.tiff
# 1/1 [==============================] - 0s 442ms/step
# Saved mask to ../../forvin/predictions\1006918_prediction.tiff
# 1/1 [==============================] - 0s 450ms/step
# Saved mask to ../../forvin/predictions\1007076_prediction.tiff
# 1/1 [==============================] - 0s 486ms/step
# Saved mask to ../../forvin/predictions\1007976_prediction.tiff
# 1/1 [==============================] - 0s 472ms/step
# Saved mask to ../../forvin/predictions\1008243_prediction.tiff
# 1/1 [==============================] - 0s 480ms/step
# Saved mask to ../../forvin/predictions\1008725_prediction.tiff
# 1/1 [==============================] - 1s 530ms/step
# Saved mask to ../../forvin/predictions\1008906_prediction.tiff
# 1/1 [==============================] - 1s 514ms/step
# Saved mask to ../../forvin/predictions\1009323_prediction.tiff
# 1/1 [==============================] - 0s 481ms/step
# Saved mask to ../../forvin/predictions\1009398_prediction.tiff
# 1/1 [==============================] - 0s 454ms/step
# Saved mask to ../../forvin/predictions\1009436_prediction.tiff
# 1/1 [==============================] - 0s 450ms/step
# Saved mask to ../../forvin/predictions\1013754_prediction.tiff
# 1/1 [==============================] - 0s 448ms/step
# Saved mask to ../../forvin/predictions\1015371_prediction.tiff
# 1/1 [==============================] - 0s 449ms/step
# Saved mask to ../../forvin/predictions\1401110_prediction.tiff
# 1/1 [==============================] - 0s 477ms/step
# Saved mask to ../../forvin/predictions\1401119_prediction.tiff
# 1/1 [==============================] - 0s 460ms/step
# Saved mask to ../../forvin/predictions\1401542_prediction.tiff
# 1/1 [==============================] - 0s 427ms/step
# Saved mask to ../../forvin/predictions\1404021_prediction.tiff
# 1/1 [==============================] - 0s 491ms/step
# Saved mask to ../../forvin/predictions\1404598_prediction.tiff
# 1/1 [==============================] - 1s 516ms/step
# Saved mask to ../../forvin/predictions\1404726_prediction.tiff
# 1/1 [==============================] - 0s 428ms/step
# Saved mask to ../../forvin/predictions\1405496_prediction.tiff
# 1/1 [==============================] - 0s 460ms/step
# Saved mask to ../../forvin/predictions\1405907_prediction.tiff
# 1/1 [==============================] - 0s 426ms/step
# Saved mask to ../../forvin/predictions\1405908_prediction.tiff
# 1/1 [==============================] - 0s 414ms/step
# Saved mask to ../../forvin/predictions\1405973_prediction.tiff
# 1/1 [==============================] - 0s 422ms/step
# Saved mask to ../../forvin/predictions\1406507_prediction.tiff
# 1/1 [==============================] - 0s 425ms/step
# Saved mask to ../../forvin/predictions\1408955_prediction.tiff
# 1/1 [==============================] - 0s 477ms/step
# Saved mask to ../../forvin/predictions\1409241_prediction.tiff
# 1/1 [==============================] - 0s 456ms/step
# Saved mask to ../../forvin/predictions\1409435_prediction.tiff
# 1/1 [==============================] - 0s 419ms/step
# Saved mask to ../../forvin/predictions\1409828_prediction.tiff
# 1/1 [==============================] - 0s 423ms/step
# Saved mask to ../../forvin/predictions\1410374_prediction.tiff
# 1/1 [==============================] - 0s 423ms/step
# Saved mask to ../../forvin/predictions\1410731_prediction.tiff
# 1/1 [==============================] - 0s 434ms/step
# Saved mask to ../../forvin/predictions\1411102_prediction.tiff
# 1/1 [==============================] - 0s 447ms/step
# Saved mask to ../../forvin/predictions\1411760_prediction.tiff
# 1/1 [==============================] - 0s 441ms/step
# Saved mask to ../../forvin/predictions\1500536_prediction.tiff
# 1/1 [==============================] - 0s 450ms/step
# Saved mask to ../../forvin/predictions\1500679_prediction.tiff
# 1/1 [==============================] - 0s 488ms/step
# Saved mask to ../../forvin/predictions\1501609_prediction.tiff
# 1/1 [==============================] - 0s 468ms/step
# Saved mask to ../../forvin/predictions\1501760_prediction.tiff
# 1/1 [==============================] - 1s 541ms/step
# Saved mask to ../../forvin/predictions\1503294_prediction.tiff
# 1/1 [==============================] - 1s 546ms/step
# Saved mask to ../../forvin/predictions\1503378_prediction.tiff
# 1/1 [==============================] - 1s 526ms/step
# Saved mask to ../../forvin/predictions\1503897_prediction.tiff
# 1/1 [==============================] - 0s 487ms/step
# Saved mask to ../../forvin/predictions\1506193_prediction.tiff
# 1/1 [==============================] - 0s 424ms/step
# Saved mask to ../../forvin/predictions\1506266_prediction.tiff
# 1/1 [==============================] - 0s 474ms/step
# Saved mask to ../../forvin/predictions\1506343_prediction.tiff
# 1/1 [==============================] - 0s 437ms/step
# Saved mask to ../../forvin/predictions\1506536_prediction.tiff
# 1/1 [==============================] - 0s 428ms/step
# Saved mask to ../../forvin/predictions\1506978_prediction.tiff
# 1/1 [==============================] - 0s 414ms/step
# Saved mask to ../../forvin/predictions\1507529_prediction.tiff
# 1/1 [==============================] - 0s 453ms/step
# Saved mask to ../../forvin/predictions\1508098_prediction.tiff
# 1/1 [==============================] - 0s 435ms/step
# Saved mask to ../../forvin/predictions\1508936_prediction.tiff
# 1/1 [==============================] - 0s 432ms/step
# Saved mask to ../../forvin/predictions\1508969_prediction.tiff
# 1/1 [==============================] - 0s 463ms/step
# Saved mask to ../../forvin/predictions\1509454_prediction.tiff
# 1/1 [==============================] - 0s 426ms/step
# Saved mask to ../../forvin/predictions\1509479_prediction.tiff
# 1/1 [==============================] - 0s 472ms/step
# Saved mask to ../../forvin/predictions\1509616_prediction.tiff
# 1/1 [==============================] - 0s 455ms/step
# Saved mask to ../../forvin/predictions\1509871_prediction.tiff
# 1/1 [==============================] - 0s 495ms/step
# Saved mask to ../../forvin/predictions\1509902_prediction.tiff
# 1/1 [==============================] - 0s 461ms/step
# Saved mask to ../../forvin/predictions\1509982_prediction.tiff
# 1/1 [==============================] - 0s 462ms/step
# Saved mask to ../../forvin/predictions\1510316_prediction.tiff
# 1/1 [==============================] - 0s 413ms/step
# Saved mask to ../../forvin/predictions\1510422_prediction.tiff
# 1/1 [==============================] - 0s 437ms/step
# Saved mask to ../../forvin/predictions\1510488_prediction.tiff
# 1/1 [==============================] - 1s 501ms/step
# Saved mask to ../../forvin/predictions\1510906_prediction.tiff
# 1/1 [==============================] - 0s 428ms/step
# Saved mask to ../../forvin/predictions\1510921_prediction.tiff
# 1/1 [==============================] - 0s 455ms/step
# Saved mask to ../../forvin/predictions\1510985_prediction.tiff
# 1/1 [==============================] - 0s 449ms/step
# Saved mask to ../../forvin/predictions\1512125_prediction.tiff
# 1/1 [==============================] - 0s 407ms/step
# Saved mask to ../../forvin/predictions\1512246_prediction.tiff
# 1/1 [==============================] - 0s 457ms/step
# Saved mask to ../../forvin/predictions\1513314_prediction.tiff
# 1/1 [==============================] - 1s 524ms/step
# Saved mask to ../../forvin/predictions\1513522_prediction.tiff
# 1/1 [==============================] - 0s 413ms/step
# Saved mask to ../../forvin/predictions\1513551_prediction.tiff
# 1/1 [==============================] - 0s 467ms/step
# Saved mask to ../../forvin/predictions\1513682_prediction.tiff
# 1/1 [==============================] - 0s 453ms/step
# Saved mask to ../../forvin/predictions\1514519_prediction.tiff
# 1/1 [==============================] - 0s 456ms/step
# Saved mask to ../../forvin/predictions\1514834_prediction.tiff
# 1/1 [==============================] - 0s 483ms/step
# Saved mask to ../../forvin/predictions\1515336_prediction.tiff
# 1/1 [==============================] - 0s 453ms/step
# Saved mask to ../../forvin/predictions\1516429_prediction.tiff
# 1/1 [==============================] - 0s 473ms/step
# Saved mask to ../../forvin/predictions\1516578_prediction.tiff
# 1/1 [==============================] - 0s 498ms/step
# Saved mask to ../../forvin/predictions\1517089_prediction.tiff
# 1/1 [==============================] - 0s 488ms/step
# Saved mask to ../../forvin/predictions\1517768_prediction.tiff
# 1/1 [==============================] - 0s 465ms/step
# Saved mask to ../../forvin/predictions\1518809_prediction.tiff
# 1/1 [==============================] - 0s 440ms/step
# Saved mask to ../../forvin/predictions\1519630_prediction.tiff
# 1/1 [==============================] - 0s 404ms/step
# Saved mask to ../../forvin/predictions\1519932_prediction.tiff
# 1/1 [==============================] - 0s 418ms/step
# Saved mask to ../../forvin/predictions\1519954_prediction.tiff
# 1/1 [==============================] - 0s 443ms/step
# Saved mask to ../../forvin/predictions\1520943_prediction.tiff
# 1/1 [==============================] - 0s 433ms/step
# Saved mask to ../../forvin/predictions\1521480_prediction.tiff
# 1/1 [==============================] - 0s 435ms/step
# Saved mask to ../../forvin/predictions\1521723_prediction.tiff
# 1/1 [==============================] - 0s 457ms/step
# Saved mask to ../../forvin/predictions\1522129_prediction.tiff
# 1/1 [==============================] - 0s 436ms/step
# Saved mask to ../../forvin/predictions\1522701_prediction.tiff
# 1/1 [==============================] - 0s 420ms/step
# Saved mask to ../../forvin/predictions\1522727_prediction.tiff
# 1/1 [==============================] - 0s 437ms/step
# Saved mask to ../../forvin/predictions\1523119_prediction.tiff
# 1/1 [==============================] - 0s 439ms/step
# Saved mask to ../../forvin/predictions\1523762_prediction.tiff
# 1/1 [==============================] - 0s 436ms/step
# Saved mask to ../../forvin/predictions\1524858_prediction.tiff
# 1/1 [==============================] - 1s 514ms/step
# Saved mask to ../../forvin/predictions\1524995_prediction.tiff
# 1/1 [==============================] - 0s 466ms/step
# Saved mask to ../../forvin/predictions\1525630_prediction.tiff
# 1/1 [==============================] - 0s 434ms/step
# Saved mask to ../../forvin/predictions\1525969_prediction.tiff
# 1/1 [==============================] - 0s 457ms/step
# Saved mask to ../../forvin/predictions\1527767_prediction.tiff
# 1/1 [==============================] - 0s 437ms/step
# Saved mask to ../../forvin/predictions\1528093_prediction.tiff
# 1/1 [==============================] - 0s 438ms/step
# Saved mask to ../../forvin/predictions\1529684_prediction.tiff
# 1/1 [==============================] - 0s 432ms/step
# Saved mask to ../../forvin/predictions\1529952_prediction.tiff
# 1/1 [==============================] - 0s 458ms/step
# Saved mask to ../../forvin/predictions\1530332_prediction.tiff
# 1/1 [==============================] - 0s 445ms/step
# Saved mask to ../../forvin/predictions\1530518_prediction.tiff
# 1/1 [==============================] - 0s 433ms/step
# Saved mask to ../../forvin/predictions\1531440_prediction.tiff
# 1/1 [==============================] - 0s 456ms/step
# Saved mask to ../../forvin/predictions\1531939_prediction.tiff
# 1/1 [==============================] - 0s 446ms/step
# Saved mask to ../../forvin/predictions\1532000_prediction.tiff
# 1/1 [==============================] - 0s 481ms/step
# Saved mask to ../../forvin/predictions\1532374_prediction.tiff
# 1/1 [==============================] - 0s 487ms/step
# Saved mask to ../../forvin/predictions\1532720_prediction.tiff
# 1/1 [==============================] - 1s 511ms/step
# Saved mask to ../../forvin/predictions\1533261_prediction.tiff
# 1/1 [==============================] - 0s 476ms/step
# Saved mask to ../../forvin/predictions\1533292_prediction.tiff
# 1/1 [==============================] - 0s 451ms/step
# Saved mask to ../../forvin/predictions\1534292_prediction.tiff
# 1/1 [==============================] - 1s 515ms/step
# Saved mask to ../../forvin/predictions\1534478_prediction.tiff
# 1/1 [==============================] - 0s 493ms/step
# Saved mask to ../../forvin/predictions\1535989_prediction.tiff
# 1/1 [==============================] - 0s 499ms/step
# Saved mask to ../../forvin/predictions\1536656_prediction.tiff
# 1/1 [==============================] - 0s 456ms/step
# Saved mask to ../../forvin/predictions\1537090_prediction.tiff
# 1/1 [==============================] - 0s 447ms/step
# Saved mask to ../../forvin/predictions\1537362_prediction.tiff
# 1/1 [==============================] - 0s 439ms/step
# Saved mask to ../../forvin/predictions\1537775_prediction.tiff
# 1/1 [==============================] - 0s 436ms/step
# Saved mask to ../../forvin/predictions\1538136_prediction.tiff
# 1/1 [==============================] - 0s 464ms/step
# Saved mask to ../../forvin/predictions\1538693_prediction.tiff
# 1/1 [==============================] - 0s 432ms/step
# Saved mask to ../../forvin/predictions\1540018_prediction.tiff
# 1/1 [==============================] - 0s 465ms/step
# Saved mask to ../../forvin/predictions\1541349_prediction.tiff
# 1/1 [==============================] - 0s 419ms/step
# Saved mask to ../../forvin/predictions\1541606_prediction.tiff
# 1/1 [==============================] - 0s 418ms/step
# Saved mask to ../../forvin/predictions\1542643_prediction.tiff
# 1/1 [==============================] - 0s 466ms/step
# Saved mask to ../../forvin/predictions\1542668_prediction.tiff
# 1/1 [==============================] - 0s 426ms/step
# Saved mask to ../../forvin/predictions\1543894_prediction.tiff
# 1/1 [==============================] - 0s 454ms/step
# Saved mask to ../../forvin/predictions\1544360_prediction.tiff
# 1/1 [==============================] - 0s 451ms/step
# Saved mask to ../../forvin/predictions\1544460_prediction.tiff
# 1/1 [==============================] - 0s 482ms/step
# Saved mask to ../../forvin/predictions\1547612_prediction.tiff
# 1/1 [==============================] - 0s 454ms/step
# Saved mask to ../../forvin/predictions\1547776_prediction.tiff
# 1/1 [==============================] - 0s 334ms/step
# Saved mask to ../../forvin/predictions\1547854_prediction.tiff
# 1/1 [==============================] - 0s 491ms/step
# Saved mask to ../../forvin/predictions\1548023_prediction.tiff
# 1/1 [==============================] - 0s 418ms/step
# Saved mask to ../../forvin/predictions\1548210_prediction.tiff
# 1/1 [==============================] - 0s 422ms/step
# Saved mask to ../../forvin/predictions\1549068_prediction.tiff
# 1/1 [==============================] - 0s 448ms/step
# Saved mask to ../../forvin/predictions\1549108_prediction.tiff
# 1/1 [==============================] - 0s 456ms/step
# Saved mask to ../../forvin/predictions\1549208_prediction.tiff
# 1/1 [==============================] - 0s 443ms/step
# Saved mask to ../../forvin/predictions\1549644_prediction.tiff
# 1/1 [==============================] - 0s 446ms/step
# Saved mask to ../../forvin/predictions\1550382_prediction.tiff
# 1/1 [==============================] - 0s 433ms/step
# Saved mask to ../../forvin/predictions\1550539_prediction.tiff
# 1/1 [==============================] - 0s 448ms/step
# Saved mask to ../../forvin/predictions\1553560_prediction.tiff
# 1/1 [==============================] - 0s 445ms/step
# Saved mask to ../../forvin/predictions\1553863_prediction.tiff
# 1/1 [==============================] - 1s 570ms/step
# Saved mask to ../../forvin/predictions\1554936_prediction.tiff
# 1/1 [==============================] - 0s 453ms/step
# Saved mask to ../../forvin/predictions\1556803_prediction.tiff
# 1/1 [==============================] - 0s 463ms/step
# Saved mask to ../../forvin/predictions\1556882_prediction.tiff
# 1/1 [==============================] - 0s 471ms/step
# Saved mask to ../../forvin/predictions\1557282_prediction.tiff
# 1/1 [==============================] - 0s 485ms/step
# Saved mask to ../../forvin/predictions\1557408_prediction.tiff
# 1/1 [==============================] - 0s 466ms/step
# Saved mask to ../../forvin/predictions\1557839_prediction.tiff
# 1/1 [==============================] - 0s 460ms/step
# Saved mask to ../../forvin/predictions\1558579_prediction.tiff
# 1/1 [==============================] - 0s 467ms/step
# Saved mask to ../../forvin/predictions\1559028_prediction.tiff
# 1/1 [==============================] - 0s 443ms/step
# Saved mask to ../../forvin/predictions\1559216_prediction.tiff
# 1/1 [==============================] - 0s 418ms/step
# Saved mask to ../../forvin/predictions\1559875_prediction.tiff
# 1/1 [==============================] - 0s 439ms/step
# Saved mask to ../../forvin/predictions\1560065_prediction.tiff
# 1/1 [==============================] - 0s 415ms/step
# Saved mask to ../../forvin/predictions\1560290_prediction.tiff
# 1/1 [==============================] - 0s 439ms/step
# Saved mask to ../../forvin/predictions\1561379_prediction.tiff
# 1/1 [==============================] - 0s 462ms/step
# Saved mask to ../../forvin/predictions\1564350_prediction.tiff
# 1/1 [==============================] - 0s 473ms/step
# Saved mask to ../../forvin/predictions\1564734_prediction.tiff
# 1/1 [==============================] - 0s 449ms/step
# Saved mask to ../../forvin/predictions\1566382_prediction.tiff
# 1/1 [==============================] - 0s 431ms/step
# Saved mask to ../../forvin/predictions\1570391_prediction.tiff
# 1/1 [==============================] - 1s 507ms/step
# Saved mask to ../../forvin/predictions\909576_prediction.tiff
# 1/1 [==============================] - 0s 459ms/step
# Saved mask to ../../forvin/predictions\911876_prediction.tiff
