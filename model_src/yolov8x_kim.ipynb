# %%
import torch
import os
from ultralytics import YOLO
import cv2
import numpy as np

# %%
model = YOLO("../models/yolov8x.pt")

# %%
# Define input directory, output directory, and list of image files
input_dir = "../dataset/box_jpg"
output_dir = "../yolo_predictions/yolov8x/box"
image_files = os.listdir(input_dir)

# Check if the output directory exists, if not, create it
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

mask_color = (250, 200, 0)

# Iterate over each image file
for image_file in image_files:
    # Load the image
    img_path = os.path.join(input_dir, image_file)
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    filename = os.path.basename(img_path) 

    # Perform inference on the image
    results = model.predict(source=img_path, conf=0.5, save=False, save_txt=False)
    masks = results[0].masks
    boxes = results[0].boxes

    # Apply the masks and boxes to the image
    for mask in masks:
        if mask is not None:
            m = torch.squeeze(mask.data)

            # Convert the tensor to numpy array
            mask_np = m.cpu().numpy().astype(np.uint8)

            # Create a colored mask
            colored_mask = np.zeros((mask_np.shape[0], mask_np.shape[1], 3), dtype=np.uint8)
            colored_mask[mask_np == 1] = mask_color

            # Resize mask to match input image size
            colored_mask = cv2.resize(colored_mask, (img.shape[1], img.shape[0]))

            # Blend the colored mask with the input image
            alpha = 0.5  # Transparency factor. You can change it as needed.
            overlayed_img = cv2.addWeighted(img, 1, colored_mask, alpha, 0)

            new_name = filename.replace('.jpg', '') + '_overlay' + '.jpg'

            # Save the image with overlayed mask
            cv2.imwrite(os.path.join(output_dir, new_name), cv2.cvtColor(overlayed_img, cv2.COLOR_RGB2BGR))
# Out:
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1506343.jpg: 320x640 1 mandible, 670.5ms
# Speed: 2.5ms preprocess, 670.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1506536.jpg: 320x640 1 mandible, 548.6ms
# Speed: 1.3ms preprocess, 548.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1507529.jpg: 320x640 1 mandible, 600.6ms
# Speed: 2.0ms preprocess, 600.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1508098.jpg: 320x640 1 mandible, 615.3ms
# Speed: 1.0ms preprocess, 615.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1508936.jpg: 320x640 1 mandible, 590.1ms
# Speed: 2.5ms preprocess, 590.1ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1509479.jpg: 320x640 2 mandibles, 599.6ms
# Speed: 2.0ms preprocess, 599.6ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1509616.jpg: 320x640 2 mandibles, 622.8ms
# Speed: 3.5ms preprocess, 622.8ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1509982-1.jpg: 320x640 1 mandible, 593.6ms
# Speed: 2.0ms preprocess, 593.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1509982.jpg: 320x640 1 mandible, 579.9ms
# Speed: 1.0ms preprocess, 579.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1510422.jpg: 320x640 1 mandible, 590.6ms
# Speed: 1.0ms preprocess, 590.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1510488.jpg: 320x640 1 mandible, 633.1ms
# Speed: 3.0ms preprocess, 633.1ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1510906.jpg: 320x640 1 mandible, 614.2ms
# Speed: 2.0ms preprocess, 614.2ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1510921.jpg: 320x640 1 mandible, 607.3ms
# Speed: 3.0ms preprocess, 607.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1510985.jpg: 320x640 1 mandible, 584.1ms
# Speed: 1.0ms preprocess, 584.1ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1512125-1.jpg: 320x640 1 mandible, 579.6ms
# Speed: 2.0ms preprocess, 579.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1512125.jpg: 320x640 1 mandible, 573.0ms
# Speed: 1.0ms preprocess, 573.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1512246.jpg: 320x640 1 mandible, 608.1ms
# Speed: 2.0ms preprocess, 608.1ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1513314.jpg: 320x640 1 mandible, 601.3ms
# Speed: 2.0ms preprocess, 601.3ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1513522.jpg: 320x640 1 mandible, 592.1ms
# Speed: 2.0ms preprocess, 592.1ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1513551.jpg: 320x640 1 mandible, 601.2ms
# Speed: 2.0ms preprocess, 601.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1513682.jpg: 320x640 1 mandible, 579.6ms
# Speed: 2.0ms preprocess, 579.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1514519.jpg: 320x640 1 mandible, 580.8ms
# Speed: 2.0ms preprocess, 580.8ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1514834.jpg: 320x640 1 mandible, 581.4ms
# Speed: 1.5ms preprocess, 581.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1516578.jpg: 320x640 1 mandible, 585.4ms
# Speed: 1.0ms preprocess, 585.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1517089.jpg: 320x640 1 mandible, 598.2ms
# Speed: 2.6ms preprocess, 598.2ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1518809-1.jpg: 320x640 1 mandible, 577.5ms
# Speed: 3.0ms preprocess, 577.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1518809.jpg: 320x640 1 mandible, 617.2ms
# Speed: 2.0ms preprocess, 617.2ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1519630.jpg: 320x640 1 mandible, 607.5ms
# Speed: 1.6ms preprocess, 607.5ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1519932.jpg: 320x640 1 mandible, 614.7ms
# Speed: 2.0ms preprocess, 614.7ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1519954.jpg: 320x640 1 mandible, 581.1ms
# Speed: 2.0ms preprocess, 581.1ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1520943.jpg: 320x640 1 mandible, 592.3ms
# Speed: 2.0ms preprocess, 592.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1521480.jpg: 320x640 1 mandible, 589.8ms
# Speed: 1.5ms preprocess, 589.8ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1521723.jpg: 320x640 1 mandible, 586.8ms
# Speed: 2.0ms preprocess, 586.8ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1522129.jpg: 320x640 1 mandible, 599.8ms
# Speed: 2.9ms preprocess, 599.8ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1522701.jpg: 320x640 1 mandible, 590.0ms
# Speed: 2.0ms preprocess, 590.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1522727.jpg: 320x640 1 mandible, 578.2ms
# Speed: 1.8ms preprocess, 578.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1523119.jpg: 320x640 1 mandible, 605.7ms
# Speed: 1.5ms preprocess, 605.7ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1523762.jpg: 320x640 1 mandible, 578.8ms
# Speed: 2.0ms preprocess, 578.8ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1524858.jpg: 320x640 1 mandible, 591.7ms
# Speed: 1.9ms preprocess, 591.7ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1524995.jpg: 320x640 1 mandible, 581.6ms
# Speed: 1.8ms preprocess, 581.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1525630.jpg: 320x640 1 mandible, 601.2ms
# Speed: 3.0ms preprocess, 601.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1525969.jpg: 320x640 1 mandible, 605.5ms
# Speed: 2.0ms preprocess, 605.5ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1527767.jpg: 320x640 1 mandible, 590.9ms
# Speed: 1.7ms preprocess, 590.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1528093.jpg: 320x640 1 mandible, 589.8ms
# Speed: 2.0ms preprocess, 589.8ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1529684-1.jpg: 320x640 1 mandible, 590.2ms
# Speed: 2.0ms preprocess, 590.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1529684.jpg: 320x640 1 mandible, 585.4ms
# Speed: 1.0ms preprocess, 585.4ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1529952.jpg: 320x640 1 mandible, 602.2ms
# Speed: 2.0ms preprocess, 602.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1530332.jpg: 320x640 1 mandible, 598.1ms
# Speed: 2.0ms preprocess, 598.1ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1530518.jpg: 320x640 1 mandible, 600.3ms
# Speed: 2.0ms preprocess, 600.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1531440.jpg: 320x640 1 mandible, 590.5ms
# Speed: 1.0ms preprocess, 590.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1531939.jpg: 320x640 1 mandible, 588.5ms
# Speed: 2.0ms preprocess, 588.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1532000.jpg: 320x640 1 mandible, 594.0ms
# Speed: 2.0ms preprocess, 594.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1532374.jpg: 320x640 1 mandible, 583.3ms
# Speed: 2.0ms preprocess, 583.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1532720.jpg: 320x640 3 mandibles, 601.2ms
# Speed: 2.0ms preprocess, 601.2ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1533261.jpg: 320x640 1 mandible, 599.1ms
# Speed: 2.0ms preprocess, 599.1ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1533292.jpg: 320x640 1 mandible, 601.6ms
# Speed: 2.0ms preprocess, 601.6ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1534292.jpg: 320x640 1 mandible, 589.5ms
# Speed: 2.0ms preprocess, 589.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1534478.jpg: 320x640 1 mandible, 607.9ms
# Speed: 2.5ms preprocess, 607.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1535989.jpg: 320x640 1 mandible, 613.4ms
# Speed: 2.0ms preprocess, 613.4ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1536656.jpg: 320x640 1 mandible, 597.3ms
# Speed: 1.1ms preprocess, 597.3ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1537090.jpg: 320x640 1 mandible, 617.8ms
# Speed: 2.0ms preprocess, 617.8ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1537362.jpg: 320x640 1 mandible, 609.2ms
# Speed: 2.0ms preprocess, 609.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1537775.jpg: 320x640 1 mandible, 597.6ms
# Speed: 2.0ms preprocess, 597.6ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\kimbe\Documents\GitHub\mandible-height-estimation\dataset\box_jpg\1538136.jpg: 320x640 (no detections), 601.1ms
# Speed: 3.0ms preprocess, 601.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 26
#      23 boxes = results[0].boxes
#      25 # Apply the masks and boxes to the image
# ---> 26 for mask in masks:
#      27     m = torch.squeeze(mask.data)
#      29     # Convert the tensor to numpy array
#
# TypeError: 'NoneType' object is not iterable
